# %% [markdown]
# # Overlap
# Some sequences from the training data can significantly overlap with data from the kinases dataset. Let's fix this data leakage.

# %% [markdown]
# ## Prepare data for mmseqs2
# Extract sequences from the training data and from the kinases data

# %%
# Read the training data sequences and input them into a .fasta file
import csv 
with open('/home/vit/Projects/LBS-pLM/data/full-LIGYSIS/full-train.txt', 'r') as f:
    reader = csv.reader(f, delimiter=';')
    with open('/home/vit/Projects/LBS-pLM/data/filtering/sequences.fasta', 'w') as fasta_file:
        for row in reader:
            seq_id = row[0]
            sequence = row[4]
            fasta_file.write(f'>{seq_id}-TRAIN\n{sequence}\n')

# %% [markdown]
# ## MMSEQS2
# After this step, the `run-mseq.sh` script needs to be run. Here, the `min-seq-id` was set to 0.3.

# %%
# Read each PDB ID, take the sequence from the MMCIF file and input it into a .fasta file
CIF_FILES_PATH = '/home/vit/Projects/deeplife-project/data/cif_files'

mapping = {'Aba': 'A', 'Ace': 'X', 'Acr': 'X', 'Ala': 'A', 'Aly': 'K', 'Arg': 'R', 'Asn': 'N', 'Asp': 'D', 'Cas': 'C',
           'Ccs': 'C', 'Cme': 'C', 'Csd': 'C', 'Cso': 'C', 'Csx': 'C', 'Cys': 'C', 'Dal': 'A', 'Dbb': 'T', 'Dbu': 'T',
           'Dha': 'S', 'Gln': 'Q', 'Glu': 'E', 'Gly': 'G', 'Glz': 'G', 'His': 'H', 'Hse': 'S', 'Ile': 'I', 'Leu': 'L',
           'Llp': 'K', 'Lys': 'K', 'Men': 'N', 'Met': 'M', 'Mly': 'K', 'Mse': 'M', 'Nh2': 'X', 'Nle': 'L', 'Ocs': 'C',
           'Pca': 'E', 'Phe': 'F', 'Pro': 'P', 'Ptr': 'Y', 'Sep': 'S', 'Ser': 'S', 'Thr': 'T', 'Tih': 'A', 'Tpo': 'T',
           'Trp': 'W', 'Tyr': 'Y', 'Unk': 'X', 'Val': 'V', 'Ycm': 'C', 'Sec': 'U', 'Pyl': 'O', 'Mhs': 'H', 'Snm': 'S',
           'Mis': 'S', 'Seb': 'S', 'Hic': 'H', 'Fme': 'M', 'Asb': 'D', 'Sah': 'C', 'Smc': 'C', 'Tpq': 'Y', 'Onl': 'X',
           'Tox': 'W', '5x8': 'X', 'Ddz': 'A'}


def three_to_one(three_letter_code):
    if three_letter_code[0].upper() + three_letter_code[1:].lower() not in mapping:
        return 'X'
    return mapping[three_letter_code[0].upper() + three_letter_code[1:].lower()]

def get_sequence(pdb_id: str, chain_id: str) -> str:
    """
    Get the amino acid sequence of a specific chain from a PDB structure.
    """
    import biotite.database.rcsb as rcsb
    import biotite.structure.io.pdbx as pdbx
    from biotite.structure.io.pdbx import get_structure
    from biotite.structure import get_residues

    cif_file_path = rcsb.fetch(pdb_id, "cif", CIF_FILES_PATH)
    cif_file = pdbx.CIFFile.read(cif_file_path)
    
    protein = get_structure(cif_file, model=1)
    protein = protein[(protein.atom_name == "CA") 
                        & (protein.element == "C") 
                        & (protein.chain_id == chain_id) ]
    _, residue_types = get_residues(protein)

    sequence = ''
    for i in range(len(residue_types)):
        amino_acid = three_to_one(residue_types[i])

        sequence += amino_acid

    return sequence

with open('/home/vit/Projects/LBS-pLM/data/kinase_pdb_chain_list.csv', 'r') as f:
    reader = csv.reader(f, delimiter=',')
    next(reader)  # Skip header
    with open('/home/vit/Projects/LBS-pLM/data/filtering/sequences.fasta', 'a') as fasta_file:
        for row in reader:
            pdb_id = row[0]
            chain_id = row[1]
            print(f'Processing {pdb_id} chain {chain_id}')
            sequence = get_sequence(pdb_id, chain_id)
            fasta_file.write(f'>{pdb_id}{chain_id}-TEST\n{sequence}\n')
# Out:
# Processing 1A9U chain A
# Processing 1AD5 chain A
# Processing 1AD5 chain B
# Processing 1AGW chain A
# Processing 1AGW chain B
# Processing 1AQ1 chain A
# Processing 1ATP chain E
# Processing 1B38 chain A
# Processing 1B39 chain A
# Processing 1BKX chain A
# Processing 1BL6 chain A
# Processing 1BL7 chain A
# Processing 1BMK chain A
# Processing 1BX6 chain A
# Processing 1BYG chain A
# Processing 1CDK chain A
# Processing 1CDK chain B
# Processing 1CKJ chain A
# Processing 1CKJ chain B
# Processing 1CKP chain A
# Processing 1CM8 chain A
# Processing 1CM8 chain B
# Processing 1CSN chain A
# Processing 1DAW chain A
# Processing 1DAY chain A
# Processing 1DI8 chain A
# Processing 1DI9 chain A
# Processing 1DM2 chain A
# Processing 1DS5 chain A
# Processing 1DS5 chain B
# Processing 1DS5 chain C
# Processing 1DS5 chain D
# Processing 1E1V chain A
# Processing 1E1X chain A
# Processing 1E9H chain A
# Processing 1E9H chain C
# Processing 1EH4 chain A
# Processing 1EH4 chain B
# Processing 1F0Q chain A
# Processing 1FGI chain A
# Processing 1FGI chain B
# Processing 1FIN chain A
# Processing 1FIN chain C
# Processing 1FMO chain E
# Processing 1FPU chain A
# Processing 1FPU chain B
# Processing 1FQ1 chain B
# Processing 1FVT chain A
# Processing 1FVV chain A
# Processing 1FVV chain C
# Processing 1G5S chain A
# Processing 1GIH chain A
# Processing 1GII chain A
# Processing 1GIJ chain A
# Processing 1GOL chain A
# Processing 1GY3 chain A
# Processing 1GY3 chain C
# Processing 1GZ8 chain A
# Processing 1H00 chain A
# Processing 1H01 chain A
# Processing 1H07 chain A
# Processing 1H08 chain A
# Processing 1H0V chain A
# Processing 1H0W chain A
# Processing 1H1P chain A
# Processing 1H1P chain C
# Processing 1H1Q chain A
# Processing 1H1Q chain C
# Processing 1H1R chain A
# Processing 1H1R chain C
# Processing 1H1S chain A
# Processing 1H1S chain C
# Processing 1H1W chain A
# Processing 1HCK chain A
# Processing 1I44 chain A
# Processing 1IEP chain A
# Processing 1IEP chain B
# Processing 1IG1 chain A
# Processing 1IR3 chain A
# Processing 1J1B chain A
# Processing 1J1B chain B
# Processing 1J1C chain A
# Processing 1J1C chain B
# Processing 1J91 chain A
# Processing 1J91 chain B
# Processing 1JBP chain E
# Processing 1JKK chain A
# Processing 1JKL chain A
# Processing 1JNK chain A
# Processing 1JPA chain A
# Processing 1JPA chain B
# Processing 1JQH chain A
# Processing 1JQH chain B
# Processing 1JQH chain C
# Processing 1JST chain A
# Processing 1JST chain C
# Processing 1JSV chain A
# Processing 1JVP chain P
# Processing 1JWH chain A
# Processing 1K3A chain A
# Processing 1KE5 chain A
# Processing 1KE6 chain A
# Processing 1KE7 chain A
# Processing 1KE8 chain A
# Processing 1KE9 chain A
# Processing 1KSW chain A
# Processing 1KV1 chain A
# Processing 1KV2 chain A
# Processing 1L3R chain E
# Processing 1LP4 chain A
# Processing 1M17 chain A
# Processing 1M2P chain A
# Processing 1M2Q chain A
# Processing 1M2R chain A
# Processing 1M52 chain A
# Processing 1M52 chain B
# Processing 1M7Q chain A
# Processing 1MP8 chain A
# Processing 1MQ4 chain A
# Processing 1MQB chain A
# Processing 1MQB chain B
# Processing 1MRU chain A
# Processing 1MRU chain B
# Processing 1MUO chain A
# Processing 1NVQ chain A
# Processing 1NVR chain A
# Processing 1NVS chain A
# Processing 1NXK chain A
# Processing 1NXK chain B
# Processing 1NXK chain C
# Processing 1NXK chain D
# Processing 1NY3 chain A
# Processing 1O6K chain A
# Processing 1O6L chain A
# Processing 1O6Y chain A
# Processing 1O9U chain A
# Processing 1OEC chain A
# Processing 1OGU chain A
# Processing 1OGU chain C
# Processing 1OI9 chain A
# Processing 1OI9 chain C
# Processing 1OIQ chain A
# Processing 1OIR chain A
# Processing 1OIT chain A
# Processing 1OIU chain A
# Processing 1OIU chain C
# Processing 1OIY chain A
# Processing 1OIY chain C
# Processing 1OKY chain A
# Processing 1OKZ chain A
# Processing 1OL5 chain A
# Processing 1OL6 chain A
# Processing 1OL7 chain A
# Processing 1OM1 chain A
# Processing 1OPJ chain A
# Processing 1OPJ chain B
# Processing 1OPK chain A
# Processing 1OPL chain A
# Processing 1OPL chain B
# Processing 1OUK chain A
# Processing 1OUY chain A
# Processing 1OVE chain A
# Processing 1OZ1 chain A
# Processing 1P2A chain A
# Processing 1P4F chain A
# Processing 1P5E chain A
# Processing 1P5E chain C
# Processing 1PF8 chain A
# Processing 1PHK chain A
# Processing 1PJK chain A
# Processing 1PKD chain A
# Processing 1PKD chain C
# Processing 1PKG chain A
# Processing 1PKG chain B
# Processing 1PME chain A
# Processing 1PMN chain A
# Processing 1PMU chain A
# Processing 1PMV chain A
# Processing 1PXI chain A
# Processing 1PXJ chain A
# Processing 1PXK chain A
# Processing 1PXL chain A
# Processing 1PXM chain A
# Processing 1PXN chain A
# Processing 1PXO chain A
# Processing 1PXP chain A
# Processing 1PY5 chain A
# Processing 1PYE chain A
# Processing 1PYX chain A
# Processing 1PYX chain B
# Processing 1Q24 chain A
# Processing 1Q3D chain A
# Processing 1Q3D chain B
# Processing 1Q3W chain A
# Processing 1Q3W chain B
# Processing 1Q41 chain A
# Processing 1Q41 chain B
# Processing 1Q4L chain A
# Processing 1Q4L chain B
# Processing 1Q5K chain A
# Processing 1Q5K chain B
# Processing 1Q8T chain A
# Processing 1Q8U chain A
# Processing 1Q8W chain A
# Processing 1Q8Y chain A
# Processing 1Q8Y chain B
# Processing 1Q97 chain A
# Processing 1Q97 chain B
# Processing 1Q99 chain A
# Processing 1Q99 chain B
# Processing 1QCF chain A
# Processing 1QL6 chain A
# Processing 1QMZ chain A
# Processing 1QMZ chain C
# Processing 1QPC chain A
# Processing 1QPD chain A
# Processing 1QPE chain A
# Processing 1QPJ chain A
# Processing 1R0E chain A
# Processing 1R0E chain B
# Processing 1R0P chain A
# Processing 1R78 chain A
# Processing 1RDQ chain E
# Processing 1RE8 chain A
# Processing 1REJ chain A
# Processing 1REK chain A
# Processing 1RW8 chain A
# Processing 1S9I chain A
# Processing 1S9I chain B
# Processing 1S9J chain A
# Processing 1SM2 chain A
# Processing 1SM2 chain B
# Processing 1SNU chain A
# Processing 1SNU chain B
# Processing 1STC chain E
# Processing 1SVE chain A
# Processing 1SVG chain A
# Processing 1SVH chain A
# Processing 1SZM chain A
# Processing 1SZM chain B
# Processing 1T46 chain A
# Processing 1TVO chain A
# Processing 1U4D chain A
# Processing 1U4D chain B
# Processing 1U54 chain A
# Processing 1U54 chain B
# Processing 1U59 chain A
# Processing 1U5R chain A
# Processing 1U5R chain B
# Processing 1UA2 chain A
# Processing 1UA2 chain B
# Processing 1UA2 chain C
# Processing 1UA2 chain D
# Processing 1UKI chain A
# Processing 1UNG chain A
# Processing 1UNG chain B
# Processing 1UNH chain A
# Processing 1UNH chain B
# Processing 1UNL chain A
# Processing 1URW chain A
# Processing 1UU3 chain A
# Processing 1UU7 chain A
# Processing 1UU8 chain A
# Processing 1UU9 chain A
# Processing 1UV5 chain A
# Processing 1UVR chain A
# Processing 1UWH chain A
# Processing 1UWH chain B
# Processing 1UWJ chain A
# Processing 1UWJ chain B
# Processing 1V0O chain A
# Processing 1V0O chain B
# Processing 1V0P chain A
# Processing 1V0P chain B
# Processing 1V1K chain A
# Processing 1VEB chain A
# Processing 1VJY chain A
# Processing 1VYW chain A
# Processing 1VYW chain C
# Processing 1VYZ chain A
# Processing 1W0X chain C
# Processing 1W7H chain A
# Processing 1W82 chain A
# Processing 1W83 chain A
# Processing 1W84 chain A
# Processing 1W8C chain A
# Processing 1WBN chain A
# Processing 1WBO chain A
# Processing 1WBP chain A
# Processing 1WBS chain A
# Processing 1WBT chain A
# Processing 1WBV chain A
# Processing 1WBW chain A
# Processing 1WCC chain A
# Processing 1WVX chain A
# Processing 1WVY chain A
# Processing 1WZY chain A
# Processing 1X8B chain A
# Processing 1XBB chain A
# Processing 1XBC chain A
# Processing 1XH4 chain A
# Processing 1XH5 chain A
# Processing 1XH6 chain A
# Processing 1XH7 chain A
# Processing 1XH8 chain A
# Processing 1XH9 chain A
# Processing 1XHA chain A
# Processing 1XJD chain A
# Processing 1XKK chain A
# Processing 1XO2 chain B
# Processing 1XR1 chain A
# Processing 1XWS chain A
# Processing 1Y57 chain A
# Processing 1Y6A chain A
# Processing 1Y6B chain A
# Processing 1Y8Y chain A
# Processing 1Y91 chain A
# Processing 1YDR chain E
# Processing 1YDS chain E
# Processing 1YDT chain E
# Processing 1YHS chain A
# Processing 1YI3 chain A
# Processing 1YI4 chain A
# Processing 1YKR chain A
# Processing 1YOL chain A
# Processing 1YOL chain B
# Processing 1YOM chain A
# Processing 1YOM chain B
# Processing 1YQJ chain A
# Processing 1YVJ chain A
# Processing 1YW2 chain A
# Processing 1YWN chain A
# Processing 1YWR chain A
# Processing 1YXT chain A
# Processing 1YXU chain A
# Processing 1YXU chain B
# Processing 1YXU chain C
# Processing 1YXU chain D
# Processing 1YXV chain A
# Processing 1YXX chain A
# Processing 1Z57 chain A
# Processing 1Z5M chain A
# Processing 1ZLT chain A
# Processing 1ZOE chain A
# Processing 1ZOG chain A
# Processing 1ZOH chain A
# Processing 1ZRZ chain A
# Processing 1ZY5 chain A
# Processing 1ZY5 chain B
# Processing 1ZYD chain A
# Processing 1ZYD chain B
# Processing 1ZYJ chain A
# Processing 1ZYS chain A
# Processing 1ZZ2 chain A
# Processing 1ZZL chain A
# Processing 2A0C chain X
# Processing 2A19 chain B
# Processing 2A19 chain C
# Processing 2A4L chain A
# Processing 2ACX chain A
# Processing 2ACX chain B
# Processing 2AYP chain A
# Processing 2B1P chain A
# Processing 2B52 chain A
# Processing 2B53 chain A
# Processing 2B54 chain A
# Processing 2B55 chain A
# Processing 2B7A chain A
# Processing 2B7A chain B
# Processing 2B9F chain A
# Processing 2B9H chain A
# Processing 2B9I chain A
# Processing 2B9J chain A
# Processing 2BAJ chain A
# Processing 2BAK chain A
# Processing 2BAL chain A
# Processing 2BAQ chain A
# Processing 2BDF chain A
# Processing 2BDF chain B
# Processing 2BDJ chain A
# Processing 2BFY chain A
# Processing 2BFY chain B
# Processing 2BHE chain A
# Processing 2BHH chain A
# Processing 2BIK chain B
# Processing 2BIL chain B
# Processing 2BIY chain A
# Processing 2BKZ chain A
# Processing 2BKZ chain C
# Processing 2BMC chain A
# Processing 2BMC chain B
# Processing 2BMC chain C
# Processing 2BMC chain D
# Processing 2BMC chain E
# Processing 2BMC chain F
# Processing 2BPM chain A
# Processing 2BPM chain C
# Processing 2BR1 chain A
# Processing 2BRB chain A
# Processing 2BRG chain A
# Processing 2BRH chain A
# Processing 2BRM chain A
# Processing 2BRN chain A
# Processing 2BRO chain A
# Processing 2BTR chain A
# Processing 2BTS chain A
# Processing 2BUJ chain A
# Processing 2BUJ chain B
# Processing 2BZH chain B
# Processing 2BZI chain B
# Processing 2BZJ chain A
# Processing 2BZK chain B
# Processing 2C0I chain A
# Processing 2C0I chain B
# Processing 2C0O chain A
# Processing 2C0O chain B
# Processing 2C0T chain A
# Processing 2C0T chain B
# Processing 2C1A chain A
# Processing 2C1B chain A
# Processing 2C3I chain B
# Processing 2C3J chain A
# Processing 2C3K chain A
# Processing 2C3L chain A
# Processing 2C47 chain A
# Processing 2C47 chain B
# Processing 2C47 chain C
# Processing 2C47 chain D
# Processing 2C4G chain A
# Processing 2C4G chain C
# Processing 2C5N chain A
# Processing 2C5N chain C
# Processing 2C5O chain A
# Processing 2C5O chain C
# Processing 2C5V chain A
# Processing 2C5V chain C
# Processing 2C5X chain A
# Processing 2C5X chain C
# Processing 2C5Y chain A
# Processing 2C68 chain A
# Processing 2C69 chain A
# Processing 2C6D chain A
# Processing 2C6E chain A
# Processing 2C6E chain B
# Processing 2C6I chain A
# Processing 2C6K chain A
# Processing 2C6L chain A
# Processing 2C6M chain A
# Processing 2C6O chain A
# Processing 2C6T chain A
# Processing 2C6T chain C
# Processing 2CCH chain A
# Processing 2CCH chain C
# Processing 2CCI chain A
# Processing 2CCI chain C
# Processing 2CDZ chain A
# Processing 2CGU chain A
# Processing 2CGV chain A
# Processing 2CGW chain A
# Processing 2CGX chain A
# Processing 2CHL chain A
# Processing 2CJM chain A
# Processing 2CJM chain C
# Processing 2CKE chain A
# Processing 2CKE chain B
# Processing 2CKE chain C
# Processing 2CKE chain D
# Processing 2CLQ chain A
# Processing 2CLQ chain B
# Processing 2CLX chain A
# Processing 2CMW chain A
# Processing 2CN5 chain A
# Processing 2CN8 chain A
# Processing 2CSN chain A
# Processing 2DQ7 chain X
# Processing 2DS1 chain A
# Processing 2DUV chain A
# Processing 2DWB chain A
# Processing 2E2B chain A
# Processing 2E2B chain B
# Processing 2E9N chain A
# Processing 2E9O chain A
# Processing 2E9P chain A
# Processing 2E9U chain A
# Processing 2E9V chain A
# Processing 2E9V chain B
# Processing 2EB3 chain A
# Processing 2ERZ chain E
# Processing 2ESM chain A
# Processing 2ESM chain B
# Processing 2ETK chain A
# Processing 2ETK chain B
# Processing 2ETM chain A
# Processing 2ETM chain B
# Processing 2ETR chain A
# Processing 2ETR chain B
# Processing 2EUF chain B
# Processing 2EVA chain A
# Processing 2EWA chain A
# Processing 2EXC chain X
# Processing 2EXM chain A
# Processing 2F2C chain B
# Processing 2F2U chain A
# Processing 2F2U chain B
# Processing 2F4J chain A
# Processing 2F57 chain B
# Processing 2F7E chain E
# Processing 2F7X chain E
# Processing 2F7Z chain E
# Processing 2F9G chain A
# Processing 2FB8 chain A
# Processing 2FB8 chain B
# Processing 2FGI chain A
# Processing 2FGI chain B
# Processing 2FO0 chain A
# Processing 2FUM chain A
# Processing 2FUM chain B
# Processing 2FUM chain C
# Processing 2FUM chain D
# Processing 2FVD chain A
# Processing 2G01 chain A
# Processing 2G01 chain B
# Processing 2G2F chain B
# Processing 2G2H chain A
# Processing 2G2H chain B
# Processing 2G2I chain A
# Processing 2G2I chain B
# Processing 2G9X chain A
# Processing 2G9X chain C
# Processing 2GCD chain A
# Processing 2GCD chain B
# Processing 2GDO chain A
# Processing 2GFS chain A
# Processing 2GHG chain A
# Processing 2GHL chain A
# Processing 2GHM chain A
# Processing 2GMX chain A
# Processing 2GMX chain B
# Processing 2GNF chain A
# Processing 2GNH chain A
# Processing 2GNI chain A
# Processing 2GNJ chain A
# Processing 2GNL chain A
# Processing 2GQG chain A
# Processing 2GQG chain B
# Processing 2GS7 chain A
# Processing 2GS7 chain B
# Processing 2GTM chain A
# Processing 2GTN chain A
# Processing 2GU8 chain A
# Processing 2H8H chain A
# Processing 2H96 chain A
# Processing 2H96 chain B
# Processing 2H9V chain A
# Processing 2HCK chain A
# Processing 2HCK chain B
# Processing 2HEN chain A
# Processing 2HEN chain B
# Processing 2HEN chain C
# Processing 2HEN chain D
# Processing 2HIW chain A
# Processing 2HIW chain B
# Processing 2HK5 chain A
# Processing 2HOG chain A
# Processing 2HW7 chain A
# Processing 2HWO chain A
# Processing 2HWO chain B
# Processing 2HWP chain A
# Processing 2HWP chain B
# Processing 2HXL chain A
# Processing 2HXQ chain A
# Processing 2HY0 chain A
# Processing 2HY8 chain 1
# Processing 2HYY chain A
# Processing 2HYY chain B
# Processing 2HYY chain C
# Processing 2HYY chain D
# Processing 2HZ0 chain A
# Processing 2HZ0 chain B
# Processing 2HZ4 chain A
# Processing 2HZ4 chain B
# Processing 2HZ4 chain C
# Processing 2HZI chain A
# Processing 2HZI chain B
# Processing 2HZN chain A
# Processing 2I0E chain A
# Processing 2I0E chain B
# Processing 2I0H chain A
# Processing 2I0V chain A
# Processing 2I0Y chain A
# Processing 2I1M chain A
# Processing 2I40 chain A
# Processing 2I40 chain C
# Processing 2IJM chain A
# Processing 2IJM chain B
# Processing 2IN6 chain A
# Processing 2IO6 chain A
# Processing 2ITN chain A
# Processing 2ITO chain A
# Processing 2ITP chain A
# Processing 2ITQ chain A
# Processing 2ITT chain A
# Processing 2ITU chain A
# Processing 2ITV chain A
# Processing 2ITW chain A
# Processing 2ITX chain A
# Processing 2ITY chain A
# Processing 2ITZ chain A
# Processing 2IVS chain A
# Processing 2IVS chain B
# Processing 2IVT chain A
# Processing 2IVU chain A
# Processing 2IVV chain A
# Processing 2IW6 chain A
# Processing 2IW6 chain C
# Processing 2IW8 chain A
# Processing 2IW8 chain C
# Processing 2IW9 chain A
# Processing 2IW9 chain C
# Processing 2IWI chain A
# Processing 2IWI chain B
# Processing 2IZR chain A
# Processing 2IZS chain A
# Processing 2IZT chain A
# Processing 2IZU chain A
# Processing 2J0J chain A
# Processing 2J0K chain A
# Processing 2J0K chain B
# Processing 2J0L chain A
# Processing 2J0M chain B
# Processing 2J2I chain B
# Processing 2J4Z chain A
# Processing 2J4Z chain B
# Processing 2J50 chain A
# Processing 2J50 chain B
# Processing 2J51 chain A
# Processing 2J5F chain A
# Processing 2J6M chain A
# Processing 2J7T chain A
# Processing 2J90 chain A
# Processing 2J90 chain B
# Processing 2J9M chain A
# Processing 2JAM chain A
# Processing 2JAM chain B
# Processing 2JAV chain A
# Processing 2JBO chain A
# Processing 2JBP chain A
# Processing 2JBP chain B
# Processing 2JBP chain C
# Processing 2JBP chain D
# Processing 2JBP chain E
# Processing 2JBP chain F
# Processing 2JBP chain G
# Processing 2JBP chain H
# Processing 2JBP chain I
# Processing 2JBP chain K
# Processing 2JBP chain L
# Processing 2JC6 chain A
# Processing 2JC6 chain C
# Processing 2JDO chain A
# Processing 2JDR chain A
# Processing 2JDS chain A
# Processing 2JDT chain A
# Processing 2JDV chain A
# Processing 2JED chain A
# Processing 2JED chain B
# Processing 2JFL chain A
# Processing 2JIU chain A
# Processing 2JIV chain A
# Processing 2JIV chain B
# Processing 2JKK chain A
# Processing 2JKM chain A
# Processing 2JKO chain A
# Processing 2JKQ chain A
# Processing 2JLD chain A
# Processing 2JLD chain B
# Processing 2NO3 chain A
# Processing 2NO3 chain B
# Processing 2NP8 chain A
# Processing 2NRU chain A
# Processing 2NRU chain B
# Processing 2NRU chain C
# Processing 2NRU chain D
# Processing 2NRY chain A
# Processing 2NRY chain B
# Processing 2NRY chain C
# Processing 2NRY chain D
# Processing 2O0U chain A
# Processing 2O2U chain A
# Processing 2O3P chain A
# Processing 2O5K chain A
# Processing 2O63 chain A
# Processing 2O64 chain A
# Processing 2O65 chain A
# Processing 2OBJ chain A
# Processing 2OF2 chain A
# Processing 2OF4 chain A
# Processing 2OFU chain A
# Processing 2OFV chain A
# Processing 2OFV chain B
# Processing 2OG8 chain A
# Processing 2OG8 chain B
# Processing 2OH0 chain E
# Processing 2OH4 chain A
# Processing 2OI4 chain X
# Processing 2OIC chain A
# Processing 2OIC chain B
# Processing 2OIC chain C
# Processing 2OIC chain D
# Processing 2OID chain A
# Processing 2OID chain B
# Processing 2OID chain C
# Processing 2OID chain D
# Processing 2OIQ chain A
# Processing 2OJ9 chain A
# Processing 2OJF chain E
# Processing 2OJG chain A
# Processing 2OJI chain A
# Processing 2OJJ chain A
# Processing 2OK1 chain A
# Processing 2OO8 chain X
# Processing 2OSC chain A
# Processing 2OU7 chain A
# Processing 2OW3 chain A
# Processing 2OW3 chain B
# Processing 2OWB chain A
# Processing 2OXD chain A
# Processing 2OXX chain A
# Processing 2OXY chain A
# Processing 2OXY chain B
# Processing 2OZO chain A
# Processing 2P0C chain A
# Processing 2P0C chain B
# Processing 2P2H chain A
# Processing 2P2I chain A
# Processing 2P2I chain B
# Processing 2P33 chain A
# Processing 2P3G chain X
# Processing 2P4I chain A
# Processing 2P4I chain B
# Processing 2P55 chain A
# Processing 2PE0 chain A
# Processing 2PE1 chain A
# Processing 2PE2 chain A
# Processing 2PHK chain A
# Processing 2PL0 chain A
# Processing 2PMI chain A
# Processing 2PML chain X
# Processing 2PMN chain X
# Processing 2PMO chain X
# Processing 2PUU chain A
# Processing 2PVF chain A
# Processing 2PVH chain A
# Processing 2PVJ chain A
# Processing 2PVK chain A
# Processing 2PVL chain A
# Processing 2PVM chain A
# Processing 2PVN chain A
# Processing 2PVR chain A
# Processing 2PVY chain A
# Processing 2PVY chain B
# Processing 2PVY chain C
# Processing 2PVY chain D
# Processing 2PWL chain A
# Processing 2PWL chain B
# Processing 2PY3 chain A
# Processing 2PY3 chain B
# Processing 2PZ5 chain A
# Processing 2PZ5 chain B
# Processing 2PZI chain A
# Processing 2PZI chain B
# Processing 2PZP chain A
# Processing 2PZP chain B
# Processing 2PZR chain A
# Processing 2PZR chain B
# Processing 2PZY chain A
# Processing 2PZY chain B
# Processing 2PZY chain C
# Processing 2Q0B chain A
# Processing 2Q0B chain B
# Processing 2QC6 chain A
# Processing 2QCS chain A
# Processing 2QD9 chain A
# Processing 2QHM chain A
# Processing 2QHN chain A
# Processing 2QKR chain A
# Processing 2QLQ chain A
# Processing 2QLQ chain B
# Processing 2QLU chain A
# Processing 2QO7 chain A
# Processing 2QO9 chain A
# Processing 2QOC chain A
# Processing 2QOH chain A
# Processing 2QOH chain B
# Processing 2QOQ chain A
# Processing 2QQ7 chain A
# Processing 2QQ7 chain B
# Processing 2QU5 chain A
# Processing 2QU6 chain A
# Processing 2QU6 chain B
# Processing 2R0U chain A
# Processing 2R3F chain A
# Processing 2R3G chain A
# Processing 2R3H chain A
# Processing 2R3I chain A
# Processing 2R3J chain A
# Processing 2R3K chain A
# Processing 2R3L chain A
# Processing 2R3M chain A
# Processing 2R3N chain A
# Processing 2R3O chain A
# Processing 2R3P chain A
# Processing 2R3Q chain A
# Processing 2R3R chain A
# Processing 2R4B chain A
# Processing 2R4B chain B
# Processing 2R5T chain A
# Processing 2R64 chain A
# Processing 2R7B chain A
# Processing 2R9S chain A
# Processing 2R9S chain B
# Processing 2RFN chain A
# Processing 2RFN chain B
# Processing 2RFS chain A
# Processing 2RG5 chain A
# Processing 2RG6 chain A
# Processing 2RGP chain A
# Processing 2RIO chain A
# Processing 2RIO chain B
# Processing 2RKU chain A
# Processing 2RL5 chain A
# Processing 2SRC chain A
# Processing 2UUE chain A
# Processing 2UUE chain C
# Processing 2UV2 chain A
# Processing 2UVX chain A
# Processing 2UVY chain A
# Processing 2UVZ chain A
# Processing 2UW0 chain A
# Processing 2UW3 chain A
# Processing 2UW4 chain A
# Processing 2UW5 chain A
# Processing 2UW6 chain A
# Processing 2UW7 chain A
# Processing 2UW8 chain A
# Processing 2UW9 chain A
# Processing 2UZB chain A
# Processing 2UZB chain C
# Processing 2UZD chain A
# Processing 2UZD chain C
# Processing 2UZE chain A
# Processing 2UZE chain C
# Processing 2UZL chain A
# Processing 2UZL chain C
# Processing 2UZN chain A
# Processing 2UZO chain A
# Processing 2UZT chain A
# Processing 2UZU chain E
# Processing 2UZV chain A
# Processing 2UZW chain E
# Processing 2V0D chain A
# Processing 2V55 chain A
# Processing 2V55 chain C
# Processing 2V7A chain A
# Processing 2V7A chain B
# Processing 2V7O chain A
# Processing 2VAG chain A
# Processing 2VD5 chain A
# Processing 2VD5 chain B
# Processing 2VGO chain A
# Processing 2VGO chain B
# Processing 2VGP chain A
# Processing 2VGP chain B
# Processing 2VN9 chain A
# Processing 2VN9 chain B
# Processing 2VNW chain A
# Processing 2VNY chain A
# Processing 2VO0 chain A
# Processing 2VO3 chain A
# Processing 2VO6 chain A
# Processing 2VO7 chain A
# Processing 2VRX chain A
# Processing 2VRX chain B
# Processing 2VTA chain A
# Processing 2VTH chain A
# Processing 2VTI chain A
# Processing 2VTJ chain A
# Processing 2VTL chain A
# Processing 2VTM chain A
# Processing 2VTN chain A
# Processing 2VTO chain A
# Processing 2VTP chain A
# Processing 2VTQ chain A
# Processing 2VTR chain A
# Processing 2VTS chain A
# Processing 2VTT chain A
# Processing 2VU3 chain A
# Processing 2VUW chain A
# Processing 2VV9 chain A
# Processing 2VWB chain A
# Processing 2VWB chain B
# Processing 2VWI chain A
# Processing 2VWI chain B
# Processing 2VWI chain C
# Processing 2VWI chain D
# Processing 2VWU chain A
# Processing 2VWV chain A
# Processing 2VWW chain A
# Processing 2VWX chain A
# Processing 2VWY chain A
# Processing 2VWZ chain A
# Processing 2VX0 chain A
# Processing 2VX1 chain A
# Processing 2VX3 chain A
# Processing 2VX3 chain B
# Processing 2VX3 chain C
# Processing 2VX3 chain D
# Processing 2VZ6 chain A
# Processing 2VZ6 chain B
# Processing 2W05 chain A
# Processing 2W06 chain A
# Processing 2W0J chain A
# Processing 2W17 chain A
# Processing 2W1C chain A
# Processing 2W1D chain A
# Processing 2W1E chain A
# Processing 2W1F chain A
# Processing 2W1G chain A
# Processing 2W1H chain A
# Processing 2W1I chain A
# Processing 2W4J chain A
# Processing 2W4K chain A
# Processing 2W4O chain A
# Processing 2W5A chain A
# Processing 2W5B chain A
# Processing 2W7X chain A
# Processing 2WAJ chain A
# Processing 2WD1 chain A
# Processing 2WEI chain A
# Processing 2WEL chain A
# Processing 2WEV chain A
# Processing 2WEV chain C
# Processing 2WGJ chain A
# Processing 2WIH chain A
# Processing 2WIH chain C
# Processing 2WIP chain A
# Processing 2WIP chain C
# Processing 2WKM chain A
# Processing 2WMQ chain A
# Processing 2WMR chain A
# Processing 2WMS chain A
# Processing 2WMT chain A
# Processing 2WMU chain A
# Processing 2WMV chain A
# Processing 2WMW chain A
# Processing 2WMX chain A
# Processing 2WO6 chain A
# Processing 2WO6 chain B
# Processing 2WOT chain A
# Processing 2WOU chain A
# Processing 2WPA chain A
# Processing 2WPA chain C
# Processing 2WQB chain A
# Processing 2WQE chain A
# Processing 2WQN chain A
# Processing 2WQO chain A
# Processing 2WTC chain A
# Processing 2WTD chain A
# Processing 2WTI chain A
# Processing 2WTJ chain A
# Processing 2WTK chain B
# Processing 2WTK chain C
# Processing 2WTK chain E
# Processing 2WTK chain F
# Processing 2WTV chain A
# Processing 2WTV chain B
# Processing 2WTV chain C
# Processing 2WTV chain D
# Processing 2WTW chain A
# Processing 2WU6 chain A
# Processing 2WU7 chain A
# Processing 2WXV chain A
# Processing 2WXV chain C
# Processing 2X1N chain A
# Processing 2X1N chain C
# Processing 2X2K chain A
# Processing 2X2L chain A
# Processing 2X2M chain A
# Processing 2X2M chain B
# Processing 2X39 chain A
# Processing 2X4F chain A
# Processing 2X4F chain B
# Processing 2X4Z chain A
# Processing 2X6D chain A
# Processing 2X6E chain A
# Processing 2X7F chain A
# Processing 2X7F chain B
# Processing 2X7F chain C
# Processing 2X7F chain D
# Processing 2X7F chain E
# Processing 2X7G chain A
# Processing 2X7O chain A
# Processing 2X7O chain B
# Processing 2X7O chain C
# Processing 2X7O chain D
# Processing 2X7O chain E
# Processing 2X81 chain A
# Processing 2X8D chain A
# Processing 2X8E chain A
# Processing 2X8I chain A
# Processing 2X9E chain A
# Processing 2X9F chain A
# Processing 2XA4 chain A
# Processing 2XA4 chain B
# Processing 2XB7 chain A
# Processing 2XBA chain A
# Processing 2XBJ chain A
# Processing 2XCH chain A
# Processing 2XCK chain A
# Processing 2XEY chain A
# Processing 2XEZ chain A
# Processing 2XF0 chain A
# Processing 2XH5 chain A
# Processing 2XIK chain A
# Processing 2XIR chain A
# Processing 2XIX chain A
# Processing 2XIY chain A
# Processing 2XIZ chain A
# Processing 2XJ0 chain A
# Processing 2XJ1 chain A
# Processing 2XJ2 chain A
# Processing 2XK3 chain A
# Processing 2XK4 chain A
# Processing 2XK6 chain A
# Processing 2XK7 chain A
# Processing 2XK8 chain A
# Processing 2XK9 chain A
# Processing 2XKC chain A
# Processing 2XKD chain A
# Processing 2XKE chain A
# Processing 2XKF chain A
# Processing 2XM8 chain A
# Processing 2XM9 chain A
# Processing 2XMY chain A
# Processing 2XNB chain A
# Processing 2XNE chain A
# Processing 2XNG chain A
# Processing 2XNM chain A
# Processing 2XNN chain A
# Processing 2XNO chain A
# Processing 2XNP chain A
# Processing 2XP2 chain A
# Processing 2XRU chain A
# Processing 2XRW chain A
# Processing 2XS0 chain A
# Processing 2XUU chain A
# Processing 2XVD chain A
# Processing 2XYN chain A
# Processing 2XYN chain B
# Processing 2XYN chain C
# Processing 2XYU chain A
# Processing 2Y4I chain B
# Processing 2Y4I chain C
# Processing 2Y6O chain A
# Processing 2Y7J chain A
# Processing 2Y7J chain B
# Processing 2Y7J chain C
# Processing 2Y7J chain D
# Processing 2Y9Q chain A
# Processing 2YA9 chain A
# Processing 2YA9 chain B
# Processing 2YAA chain A
# Processing 2YAA chain B
# Processing 2YAB chain A
# Processing 2YAB chain B
# Processing 2YAC chain A
# Processing 2YAK chain A
# Processing 2YCF chain A
# Processing 2YCQ chain A
# Processing 2YCR chain A
# Processing 2YCS chain A
# Processing 2YDI chain A
# Processing 2YDJ chain A
# Processing 2YDJ chain B
# Processing 2YDK chain A
# Processing 2YER chain A
# Processing 2YEX chain A
# Processing 2YFX chain A
# Processing 2YIQ chain A
# Processing 2YIR chain A
# Processing 2YIS chain A
# Processing 2YIT chain A
# Processing 2YIW chain A
# Processing 2YIX chain A
# Processing 2YIY chain A
# Processing 2YM3 chain A
# Processing 2YM4 chain A
# Processing 2YM5 chain A
# Processing 2YM6 chain A
# Processing 2YM7 chain A
# Processing 2YM8 chain A
# Processing 2YN8 chain A
# Processing 2YN8 chain B
# Processing 2YWP chain A
# Processing 2Z2W chain A
# Processing 2Z60 chain A
# Processing 2Z7L chain A
# Processing 2Z7Q chain A
# Processing 2Z7R chain A
# Processing 2Z7S chain A
# Processing 2Z8C chain A
# Processing 2ZAZ chain A
# Processing 2ZB0 chain A
# Processing 2ZB1 chain A
# Processing 2ZDT chain A
# Processing 2ZDU chain A
# Processing 2ZJW chain A
# Processing 2ZM1 chain A
# Processing 2ZM3 chain A
# Processing 2ZM3 chain B
# Processing 2ZM3 chain C
# Processing 2ZM3 chain D
# Processing 2ZM4 chain A
# Processing 2ZMD chain A
# Processing 2ZOQ chain A
# Processing 2ZOQ chain B
# Processing 2ZV2 chain A
# Processing 2ZV8 chain A
# Processing 2ZV9 chain A
# Processing 2ZVA chain A
# Processing 2ZYB chain A
# Processing 3A2C chain A
# Processing 3A2C chain B
# Processing 3A2C chain C
# Processing 3A2C chain D
# Processing 3A2C chain E
# Processing 3A2C chain F
# Processing 3A2C chain G
# Processing 3A2C chain H
# Processing 3A2C chain I
# Processing 3A2C chain J
# Processing 3A2C chain K
# Processing 3A2C chain L
# Processing 3A4O chain X
# Processing 3A4P chain A
# Processing 3A60 chain A
# Processing 3A60 chain B
# Processing 3A61 chain A
# Processing 3A62 chain A
# Processing 3A7H chain A
# Processing 3A7H chain B
# Processing 3A7I chain A
# Processing 3A7J chain A
# Processing 3A8W chain A
# Processing 3A8W chain B
# Processing 3A99 chain A
# Processing 3AC1 chain A
# Processing 3AC2 chain A
# Processing 3AC3 chain A
# Processing 3AC4 chain A
# Processing 3AC5 chain A
# Processing 3AC8 chain A
# Processing 3ACJ chain A
# Processing 3ACK chain A
# Processing 3AD4 chain A
# Processing 3AD5 chain A
# Processing 3AD6 chain A
# Processing 3AG9 chain B
# Processing 3AGL chain A
# Processing 3AGL chain B
# Processing 3ALN chain A
# Processing 3ALN chain B
# Processing 3ALN chain C
# Processing 3ALO chain A
# Processing 3AMA chain A
# Processing 3AMB chain A
# Processing 3AMY chain A
# Processing 3ANQ chain A
# Processing 3ANQ chain B
# Processing 3ANQ chain C
# Processing 3ANQ chain D
# Processing 3ANR chain A
# Processing 3ANR chain B
# Processing 3ANR chain C
# Processing 3ANR chain D
# Processing 3AOX chain A
# Processing 3AQV chain A
# Processing 3AT3 chain A
# Processing 3AT4 chain A
# Processing 3AXW chain A
# Processing 3B2T chain A
# Processing 3B2T chain B
# Processing 3B2W chain A
# Processing 3B8Q chain A
# Processing 3B8Q chain B
# Processing 3B8R chain A
# Processing 3B8R chain B
# Processing 3BBT chain B
# Processing 3BBT chain D
# Processing 3BE2 chain A
# Processing 3BE9 chain A
# Processing 3BEA chain A
# Processing 3BEG chain A
# Processing 3BEL chain A
# Processing 3BGP chain A
# Processing 3BGQ chain A
# Processing 3BGZ chain A
# Processing 3BHH chain A
# Processing 3BHH chain B
# Processing 3BHT chain A
# Processing 3BHT chain C
# Processing 3BHU chain A
# Processing 3BHU chain C
# Processing 3BHV chain A
# Processing 3BHV chain C
# Processing 3BHY chain A
# Processing 3BI6 chain A
# Processing 3BIZ chain A
# Processing 3BKB chain A
# Processing 3BLQ chain A
# Processing 3BLR chain A
# Processing 3BPR chain A
# Processing 3BPR chain B
# Processing 3BPR chain C
# Processing 3BPR chain D
# Processing 3BQC chain A
# Processing 3BQR chain A
# Processing 3BRB chain A
# Processing 3BRB chain B
# Processing 3BU5 chain A
# Processing 3BV2 chain A
# Processing 3BV3 chain A
# Processing 3BWF chain A
# Processing 3BWJ chain A
# Processing 3BX5 chain A
# Processing 3BYM chain A
# Processing 3BYO chain A
# Processing 3BYS chain A
# Processing 3BYU chain A
# Processing 3BZ3 chain A
# Processing 3C0G chain A
# Processing 3C0G chain B
# Processing 3C0H chain A
# Processing 3C0H chain B
# Processing 3C0I chain A
# Processing 3C13 chain A
# Processing 3C1X chain A
# Processing 3C4C chain A
# Processing 3C4C chain B
# Processing 3C4E chain A
# Processing 3C4E chain B
# Processing 3C4E chain C
# Processing 3C4E chain D
# Processing 3C4F chain A
# Processing 3C4F chain B
# Processing 3C4W chain A
# Processing 3C4W chain B
# Processing 3C4X chain A
# Processing 3C4X chain B
# Processing 3C4Z chain A
# Processing 3C50 chain A
# Processing 3C50 chain B
# Processing 3C51 chain A
# Processing 3C51 chain B
# Processing 3C5U chain A
# Processing 3C7Q chain A
# Processing 3C9W chain A
# Processing 3C9W chain B
# Processing 3CBL chain A
# Processing 3CCN chain A
# Processing 3CD3 chain A
# Processing 3CD8 chain A
# Processing 3CE3 chain A
# Processing 3CGF chain A
# Processing 3CGO chain A
# Processing 3CJF chain A
# Processing 3CJG chain A
# Processing 3CKX chain A
# Processing 3CLY chain A
# Processing 3COH chain A
# Processing 3COH chain B
# Processing 3COK chain A
# Processing 3COK chain B
# Processing 3CP9 chain A
# Processing 3CP9 chain B
# Processing 3CPB chain A
# Processing 3CPB chain B
# Processing 3CPC chain A
# Processing 3CPC chain B
# Processing 3CQE chain A
# Processing 3CQU chain A
# Processing 3CQW chain A
# Processing 3CR0 chain A
# Processing 3CS9 chain A
# Processing 3CS9 chain B
# Processing 3CS9 chain C
# Processing 3CS9 chain D
# Processing 3CTH chain A
# Processing 3CTJ chain A
# Processing 3CTQ chain A
# Processing 3CXW chain A
# Processing 3CY2 chain A
# Processing 3CY3 chain A
# Processing 3D0E chain A
# Processing 3D0E chain B
# Processing 3D14 chain A
# Processing 3D15 chain A
# Processing 3D2I chain A
# Processing 3D2K chain A
# Processing 3D4Q chain A
# Processing 3D4Q chain B
# Processing 3D5W chain A
# Processing 3D5X chain A
# Processing 3D7T chain A
# Processing 3D7T chain B
# Processing 3D7Z chain A
# Processing 3D83 chain A
# Processing 3D94 chain A
# Processing 3D9V chain A
# Processing 3D9V chain B
# Processing 3DA6 chain A
# Processing 3DAJ chain A
# Processing 3DAK chain A
# Processing 3DAK chain B
# Processing 3DAK chain C
# Processing 3DAK chain D
# Processing 3DB6 chain A
# Processing 3DB8 chain A
# Processing 3DBC chain A
# Processing 3DBD chain A
# Processing 3DBE chain A
# Processing 3DBF chain A
# Processing 3DCV chain A
# Processing 3DDP chain A
# Processing 3DDP chain C
# Processing 3DDQ chain A
# Processing 3DDQ chain C
# Processing 3DFC chain B
# Processing 3DJ5 chain A
# Processing 3DJ6 chain A
# Processing 3DJ7 chain A
# Processing 3DK3 chain A
# Processing 3DK3 chain B
# Processing 3DK6 chain A
# Processing 3DK6 chain B
# Processing 3DK7 chain A
# Processing 3DK7 chain B
# Processing 3DKC chain A
# Processing 3DKF chain A
# Processing 3DKG chain A
# Processing 3DKO chain A
# Processing 3DLS chain A
# Processing 3DLS chain B
# Processing 3DLS chain C
# Processing 3DLS chain D
# Processing 3DLS chain E
# Processing 3DLS chain F
# Processing 3DLZ chain A
# Processing 3DND chain A
# Processing 3DNE chain A
# Processing 3DOG chain A
# Processing 3DOG chain C
# Processing 3DPK chain A
# Processing 3DQW chain A
# Processing 3DQW chain B
# Processing 3DQW chain C
# Processing 3DQW chain D
# Processing 3DQX chain A
# Processing 3DQX chain B
# Processing 3DS6 chain A
# Processing 3DS6 chain B
# Processing 3DS6 chain C
# Processing 3DS6 chain D
# Processing 3DT1 chain A
# Processing 3DTC chain A
# Processing 3DTW chain A
# Processing 3DTW chain B
# Processing 3DU8 chain A
# Processing 3DU8 chain B
# Processing 3DV3 chain A
# Processing 3DY7 chain A
# Processing 3DZQ chain A
# Processing 3E3B chain X
# Processing 3E5A chain A
# Processing 3E62 chain A
# Processing 3E63 chain A
# Processing 3E64 chain A
# Processing 3E7O chain A
# Processing 3E7O chain B
# Processing 3E7V chain A
# Processing 3E87 chain A
# Processing 3E87 chain B
# Processing 3E88 chain A
# Processing 3E88 chain B
# Processing 3E8C chain A
# Processing 3E8C chain B
# Processing 3E8C chain C
# Processing 3E8C chain D
# Processing 3E8C chain E
# Processing 3E8C chain F
# Processing 3E8D chain A
# Processing 3E8D chain B
# Processing 3E8E chain A
# Processing 3E8E chain B
# Processing 3E8E chain E
# Processing 3E8E chain I
# Processing 3E8E chain L
# Processing 3E8E chain P
# Processing 3E8N chain A
# Processing 3E92 chain A
# Processing 3E93 chain A
# Processing 3EB0 chain A
# Processing 3EB0 chain C
# Processing 3EFJ chain A
# Processing 3EFJ chain B
# Processing 3EFK chain A
# Processing 3EFK chain B
# Processing 3EFL chain A
# Processing 3EFL chain B
# Processing 3EFW chain A
# Processing 3EFW chain B
# Processing 3EH9 chain A
# Processing 3EHA chain A
# Processing 3EID chain A
# Processing 3EJ1 chain A
# Processing 3EJ1 chain C
# Processing 3EKK chain A
# Processing 3EKN chain A
# Processing 3EL7 chain A
# Processing 3EL8 chain A
# Processing 3ELJ chain A
# Processing 3EMG chain A
# Processing 3EN4 chain A
# Processing 3EN4 chain B
# Processing 3EN5 chain A
# Processing 3EN5 chain B
# Processing 3EN6 chain B
# Processing 3EN7 chain A
# Processing 3EN9 chain A
# Processing 3EN9 chain B
# Processing 3ENH chain A
# Processing 3ENH chain B
# Processing 3EOC chain A
# Processing 3EOC chain C
# Processing 3EQB chain A
# Processing 3EQC chain A
# Processing 3EQD chain A
# Processing 3EQF chain A
# Processing 3EQG chain A
# Processing 3EQH chain A
# Processing 3EQI chain A
# Processing 3EQP chain A
# Processing 3EQP chain B
# Processing 3EQR chain A
# Processing 3EQR chain B
# Processing 3ERK chain A
# Processing 3ET7 chain A
# Processing 3ETA chain A
# Processing 3ETA chain B
# Processing 3EWH chain A
# Processing 3EYG chain A
# Processing 3EYH chain A
# Processing 3EZR chain A
# Processing 3EZV chain A
# Processing 3F2A chain A
# Processing 3F2N chain A
# Processing 3F3T chain A
# Processing 3F3U chain A
# Processing 3F3U chain B
# Processing 3F3V chain A
# Processing 3F3V chain B
# Processing 3F3W chain A
# Processing 3F3W chain B
# Processing 3F3Z chain A
# Processing 3F5G chain A
# Processing 3F5P chain A
# Processing 3F5P chain B
# Processing 3F5P chain C
# Processing 3F5P chain D
# Processing 3F5P chain E
# Processing 3F5P chain F
# Processing 3F5P chain G
# Processing 3F5P chain H
# Processing 3F5P chain I
# Processing 3F5P chain J
# Processing 3F5P chain K
# Processing 3F5P chain L
# Processing 3F5P chain M
# Processing 3F5P chain R
# Processing 3F5P chain S
# Processing 3F5P chain T
# Processing 3F5U chain A
# Processing 3F5X chain A
# Processing 3F5X chain C
# Processing 3F61 chain A
# Processing 3F66 chain A
# Processing 3F66 chain B
# Processing 3F69 chain A
# Processing 3F69 chain B
# Processing 3F6X chain A
# Processing 3F6X chain B
# Processing 3F6X chain C
# Processing 3F6X chain D
# Processing 3F7Z chain A
# Processing 3F7Z chain B
# Processing 3F82 chain A
# Processing 3F88 chain A
# Processing 3F88 chain B
# Processing 3F9N chain A
# Processing 3FAA chain A
# Processing 3FAA chain B
# Processing 3FAA chain C
# Processing 3FAA chain D
# Processing 3FAA chain E
# Processing 3FBV chain A
# Processing 3FBV chain B
# Processing 3FBV chain C
# Processing 3FBV chain D
# Processing 3FBV chain E
# Processing 3FBV chain F
# Processing 3FBV chain G
# Processing 3FBV chain H
# Processing 3FBV chain I
# Processing 3FBV chain J
# Processing 3FBV chain K
# Processing 3FBV chain L
# Processing 3FBV chain M
# Processing 3FBV chain N
# Processing 3FC1 chain X
# Processing 3FC2 chain A
# Processing 3FDN chain A
# Processing 3FHI chain A
# Processing 3FHR chain A
# Processing 3FI2 chain A
# Processing 3FI3 chain A
# Processing 3FI4 chain A
# Processing 3FJQ chain E
# Processing 3FKL chain A
# Processing 3FKN chain A
# Processing 3FKO chain A
# Processing 3FL4 chain A
# Processing 3FL5 chain A
# Processing 3FLN chain C
# Processing 3FLQ chain A
# Processing 3FLS chain A
# Processing 3FLW chain A
# Processing 3FLY chain A
# Processing 3FLZ chain A
# Processing 3FMD chain A
# Processing 3FME chain A
# Processing 3FMH chain A
# Processing 3FMJ chain A
# Processing 3FMK chain A
# Processing 3FML chain A
# Processing 3FMM chain A
# Processing 3FMN chain A
# Processing 3FPM chain A
# Processing 3FQE chain A
# Processing 3FQH chain A
# Processing 3FQH chain B
# Processing 3FQS chain A
# Processing 3FSF chain A
# Processing 3FSK chain A
# Processing 3FUP chain A
# Processing 3FUP chain B
# Processing 3FV8 chain A
# Processing 3FXW chain A
# Processing 3FXX chain A
# Processing 3FXZ chain A
# Processing 3FY0 chain A
# Processing 3FYJ chain X
# Processing 3FYK chain X
# Processing 3FZ1 chain A
# Processing 3FZP chain A
# Processing 3FZR chain A
# Processing 3FZS chain A
# Processing 3FZT chain A
# Processing 3G0E chain A
# Processing 3G0F chain A
# Processing 3G0F chain B
# Processing 3G2F chain A
# Processing 3G2F chain B
# Processing 3G51 chain A
# Processing 3G5D chain A
# Processing 3G5D chain B
# Processing 3G6G chain A
# Processing 3G6G chain B
# Processing 3G6H chain B
# Processing 3G90 chain X
# Processing 3G9L chain X
# Processing 3G9N chain A
# Processing 3GB2 chain A
# Processing 3GC0 chain A
# Processing 3GC7 chain A
# Processing 3GC8 chain A
# Processing 3GC8 chain B
# Processing 3GC9 chain A
# Processing 3GC9 chain B
# Processing 3GCP chain A
# Processing 3GCQ chain A
# Processing 3GCS chain A
# Processing 3GCU chain A
# Processing 3GCU chain B
# Processing 3GCV chain A
# Processing 3GEN chain A
# Processing 3GEQ chain A
# Processing 3GEQ chain B
# Processing 3GFE chain A
# Processing 3GFW chain A
# Processing 3GGF chain A
# Processing 3GGF chain B
# Processing 3GI3 chain A
# Processing 3GNI chain B
# Processing 3GOK chain A
# Processing 3GOK chain B
# Processing 3GOK chain C
# Processing 3GOK chain D
# Processing 3GOK chain E
# Processing 3GOK chain F
# Processing 3GOK chain G
# Processing 3GOK chain H
# Processing 3GOK chain I
# Processing 3GOK chain J
# Processing 3GOK chain K
# Processing 3GOK chain L
# Processing 3GP0 chain A
# Processing 3GQI chain A
# Processing 3GQL chain A
# Processing 3GQL chain B
# Processing 3GQL chain C
# Processing 3GT8 chain A
# Processing 3GT8 chain B
# Processing 3GT8 chain C
# Processing 3GT8 chain D
# Processing 3GU4 chain A
# Processing 3GU5 chain A
# Processing 3GU6 chain A
# Processing 3GU7 chain A
# Processing 3GU8 chain A
# Processing 3GUB chain A
# Processing 3GVU chain A
# Processing 3GXL chain A
# Processing 3H0Y chain A
# Processing 3H0Z chain A
# Processing 3H0Z chain B
# Processing 3H0Z chain C
# Processing 3H10 chain A
# Processing 3H10 chain B
# Processing 3H10 chain D
# Processing 3H30 chain A
# Processing 3H30 chain B
# Processing 3H3C chain A
# Processing 3H9F chain A
# Processing 3H9O chain A
# Processing 3H9R chain A
# Processing 3HA6 chain A
# Processing 3HA8 chain A
# Processing 3HDM chain A
# Processing 3HDN chain A
# Processing 3HEC chain A
# Processing 3HEG chain A
# Processing 3HKO chain A
# Processing 3HL7 chain A
# Processing 3HLL chain A
# Processing 3HMI chain A
# Processing 3HMM chain A
# Processing 3HMN chain A
# Processing 3HMO chain A
# Processing 3HMP chain A
# Processing 3HNG chain A
# Processing 3HP2 chain A
# Processing 3HP5 chain A
# Processing 3HRB chain A
# Processing 3HRC chain A
# Processing 3HRF chain A
# Processing 3HUB chain A
# Processing 3HUC chain A
# Processing 3HV3 chain A
# Processing 3HV4 chain A
# Processing 3HV4 chain B
# Processing 3HV5 chain A
# Processing 3HV5 chain B
# Processing 3HV6 chain A
# Processing 3HV7 chain A
# Processing 3HX4 chain A
# Processing 3HZT chain A
# Processing 3I4B chain A
# Processing 3I4B chain B
# Processing 3I5N chain A
# Processing 3I5Z chain A
# Processing 3I60 chain A
# Processing 3I7B chain A
# Processing 3I7C chain A
# Processing 3I81 chain A
# Processing 3IDB chain A
# Processing 3IDC chain A
# Processing 3IDP chain A
# Processing 3IDP chain B
# Processing 3IG7 chain A
# Processing 3IGG chain A
# Processing 3IGO chain A
# Processing 3II5 chain A
# Processing 3II5 chain B
# Processing 3IK3 chain A
# Processing 3IK3 chain B
# Processing 3IKA chain A
# Processing 3IO7 chain A
# Processing 3IOK chain A
# Processing 3ION chain A
# Processing 3IOP chain A
# Processing 3IPH chain A
# Processing 3IQ7 chain A
# Processing 3ITZ chain A
# Processing 3IW4 chain A
# Processing 3IW4 chain B
# Processing 3IW4 chain C
# Processing 3IW5 chain A
# Processing 3IW6 chain A
# Processing 3IW7 chain A
# Processing 3IW8 chain A
# Processing 3JPV chain A
# Processing 3JS2 chain A
# Processing 3JS2 chain B
# Processing 3JUH chain A
# Processing 3JUH chain B
# Processing 3JVR chain A
# Processing 3JVS chain A
# Processing 3JXW chain A
# Processing 3JY0 chain A
# Processing 3JY9 chain A
# Processing 3JYA chain A
# Processing 3K3I chain A
# Processing 3K3J chain A
# Processing 3K54 chain A
# Processing 3K5U chain A
# Processing 3K5V chain A
# Processing 3K5V chain B
# Processing 3KA0 chain A
# Processing 3KB7 chain A
# Processing 3KC3 chain A
# Processing 3KC3 chain B
# Processing 3KC3 chain C
# Processing 3KC3 chain D
# Processing 3KC3 chain E
# Processing 3KC3 chain F
# Processing 3KC3 chain H
# Processing 3KC3 chain I
# Processing 3KC3 chain J
# Processing 3KC3 chain K
# Processing 3KC3 chain L
# Processing 3KCF chain A
# Processing 3KCF chain B
# Processing 3KCF chain C
# Processing 3KCF chain D
# Processing 3KCF chain E
# Processing 3KCK chain A
# Processing 3KEX chain A
# Processing 3KEX chain B
# Processing 3KF4 chain A
# Processing 3KF4 chain B
# Processing 3KF7 chain A
# Processing 3KFA chain A
# Processing 3KFA chain B
# Processing 3KGA chain A
# Processing 3KKV chain A
# Processing 3KMM chain A
# Processing 3KMW chain A
# Processing 3KN5 chain A
# Processing 3KN5 chain B
# Processing 3KQ7 chain A
# Processing 3KRJ chain A
# Processing 3KRL chain A
# Processing 3KRR chain A
# Processing 3KRW chain A
# Processing 3KRX chain A
# Processing 3KU2 chain A
# Processing 3KVW chain A
# Processing 3KVX chain A
# Processing 3KXG chain A
# Processing 3KXH chain A
# Processing 3KXM chain A
# Processing 3KXN chain A
# Processing 3KXZ chain A
# Processing 3L1S chain A
# Processing 3L1S chain B
# Processing 3L8P chain A
# Processing 3L8S chain A
# Processing 3L8V chain A
# Processing 3L8X chain A
# Processing 3L9L chain A
# Processing 3L9L chain B
# Processing 3L9M chain A
# Processing 3L9M chain B
# Processing 3L9N chain A
# Processing 3LAU chain A
# Processing 3LCD chain A
# Processing 3LCO chain A
# Processing 3LCS chain A
# Processing 3LCT chain A
# Processing 3LE6 chain A
# Processing 3LFA chain A
# Processing 3LFB chain A
# Processing 3LFC chain A
# Processing 3LFD chain A
# Processing 3LFE chain A
# Processing 3LFF chain A
# Processing 3LFN chain A
# Processing 3LFQ chain A
# Processing 3LFS chain A
# Processing 3LHJ chain A
# Processing 3LIJ chain A
# Processing 3LJ0 chain A
# Processing 3LJ0 chain B
# Processing 3LJ1 chain A
# Processing 3LJ1 chain B
# Processing 3LJ2 chain A
# Processing 3LJ2 chain B
# Processing 3LLT chain A
# Processing 3LM0 chain A
# Processing 3LM5 chain A
# Processing 3LMG chain A
# Processing 3LMG chain B
# Processing 3LOK chain A
# Processing 3LOK chain B
# Processing 3LPB chain A
# Processing 3LPB chain B
# Processing 3LQ5 chain A
# Processing 3LQ8 chain A
# Processing 3LVP chain A
# Processing 3LVP chain B
# Processing 3LVP chain C
# Processing 3LVP chain D
# Processing 3LW0 chain A
# Processing 3LW0 chain B
# Processing 3LW0 chain C
# Processing 3LW0 chain D
# Processing 3LXK chain A
# Processing 3LXL chain A
# Processing 3LXN chain A
# Processing 3LXP chain A
# Processing 3LZB chain A
# Processing 3LZB chain B
# Processing 3LZB chain C
# Processing 3LZB chain D
# Processing 3M11 chain A
# Processing 3M1S chain A
# Processing 3M1S chain B
# Processing 3M2W chain A
# Processing 3M42 chain A
# Processing 3MA3 chain A
# Processing 3MA6 chain A
# Processing 3MA6 chain B
# Processing 3MB6 chain A
# Processing 3MB7 chain A
# Processing 3MBL chain A
# Processing 3MDY chain A
# Processing 3MDY chain C
# Processing 3MFR chain A
# Processing 3MFS chain A
# Processing 3MFU chain A
# Processing 3MIA chain A
# Processing 3MIY chain A
# Processing 3MIY chain B
# Processing 3MJ1 chain A
# Processing 3MJ2 chain A
# Processing 3MPA chain A
# Processing 3MPM chain A
# Processing 3MPT chain A
# Processing 3MS9 chain A
# Processing 3MS9 chain B
# Processing 3MSS chain A
# Processing 3MSS chain B
# Processing 3MSS chain C
# Processing 3MSS chain D
# Processing 3MTF chain A
# Processing 3MTF chain B
# Processing 3MTL chain A
# Processing 3MV5 chain A
# Processing 3MVH chain A
# Processing 3MVJ chain A
# Processing 3MVJ chain E
# Processing 3MVL chain A
# Processing 3MVL chain B
# Processing 3MVM chain A
# Processing 3MVM chain B
# Processing 3MW1 chain A
# Processing 3MWU chain A
# Processing 3MY0 chain A
# Processing 3MY0 chain B
# Processing 3MY0 chain C
# Processing 3MY0 chain D
# Processing 3MY0 chain E
# Processing 3MY0 chain F
# Processing 3MY0 chain G
# Processing 3MY0 chain H
# Processing 3MY0 chain I
# Processing 3MY0 chain J
# Processing 3MY0 chain K
# Processing 3MY0 chain L
# Processing 3MY0 chain M
# Processing 3MY0 chain N
# Processing 3MY0 chain O
# Processing 3MY0 chain P
# Processing 3MY0 chain Q
# Processing 3MY0 chain R
# Processing 3MY0 chain S
# Processing 3MY0 chain T
# Processing 3MY0 chain U
# Processing 3MY0 chain V
# Processing 3MY0 chain W
# Processing 3MY0 chain X
# Processing 3MY1 chain A
# Processing 3MY5 chain A
# Processing 3MY5 chain C
# Processing 3MYG chain A
# Processing 3N51 chain A
# Processing 3NAX chain A
# Processing 3NAY chain A
# Processing 3NAY chain B
# Processing 3NCG chain A
# Processing 3NCZ chain A
# Processing 3NCZ chain B
# Processing 3NCZ chain C
# Processing 3NCZ chain D
# Processing 3NDM chain B
# Processing 3NDM chain C
# Processing 3NDM chain D
# Processing 3NEW chain A
# Processing 3NGA chain A
# Processing 3NGA chain B
# Processing 3NIE chain A
# Processing 3NIE chain B
# Processing 3NIZ chain A
# Processing 3NLB chain A
# Processing 3NNU chain A
# Processing 3NNV chain A
# Processing 3NNW chain A
# Processing 3NNX chain A
# Processing 3NPC chain A
# Processing 3NPC chain B
# Processing 3NR9 chain A
# Processing 3NR9 chain B
# Processing 3NR9 chain C
# Processing 3NRM chain A
# Processing 3NS9 chain A
# Processing 3NSZ chain A
# Processing 3NUN chain A
# Processing 3NUP chain A
# Processing 3NUS chain A
# Processing 3NUU chain A
# Processing 3NUX chain A
# Processing 3NUY chain A
# Processing 3NW5 chain A
# Processing 3NW6 chain A
# Processing 3NW7 chain A
# Processing 3NWW chain A
# Processing 3NYN chain A
# Processing 3NYN chain B
# Processing 3NYO chain A
# Processing 3NYO chain B
# Processing 3NYV chain A
# Processing 3NYX chain A
# Processing 3NZ0 chain A
# Processing 3O0G chain B
# Processing 3O23 chain A
# Processing 3O2M chain A
# Processing 3O2M chain B
# Processing 3O50 chain A
# Processing 3O50 chain B
# Processing 3O51 chain A
# Processing 3O7L chain B
# Processing 3O8P chain A
# Processing 3O8T chain A
# Processing 3O8U chain A
# Processing 3O96 chain A
# Processing 3OBG chain A
# Processing 3OBJ chain A
# Processing 3OC1 chain A
# Processing 3OCB chain A
# Processing 3OCB chain B
# Processing 3OCG chain A
# Processing 3OCS chain A
# Processing 3OCT chain A
# Processing 3OEZ chain A
# Processing 3OEZ chain B
# Processing 3OFM chain A
# Processing 3OG7 chain A
# Processing 3OHT chain A
# Processing 3OHT chain B
# Processing 3OMV chain A
# Processing 3OMV chain B
# Processing 3OOG chain A
# Processing 3OOM chain A
# Processing 3OP5 chain A
# Processing 3OP5 chain B
# Processing 3OP5 chain C
# Processing 3OP5 chain D
# Processing 3ORI chain A
# Processing 3ORI chain B
# Processing 3ORI chain C
# ...
# Processing 3PXQ chain A
# Processing 3PXY chain A
# Processing 3PXZ chain A
# Processing 3PY0 chain A
# Processing 3PY1 chain A
# Processing 3PYY chain A
# Processing 3PYY chain B
# Processing 3PZE chain A
# Processing 3PZH chain A
# Processing 3Q32 chain A
# Processing 3Q32 chain B
# Processing 3Q3B chain A
# Processing 3Q3B chain B
# Processing 3Q4C chain A
# Processing 3Q4T chain A
# Processing 3Q4T chain B
# Processing 3Q4U chain A
# Processing 3Q4U chain B
# Processing 3Q4U chain C
# Processing 3Q4U chain D
# Processing 3Q4Z chain A
# Processing 3Q53 chain A
# Processing 3Q5I chain A
# Processing 3Q6U chain A
# Processing 3Q6W chain A
# Processing 3Q96 chain A
# Processing 3Q96 chain B
# Processing 3Q9W chain A
# Processing 3Q9X chain A
# Processing 3Q9X chain B
# Processing 3Q9Y chain A
# Processing 3Q9Z chain A
# Processing 3Q9Z chain B
# Processing 3QAL chain E
# Processing 3QAM chain E
# Processing 3QBN chain A
# Processing 3QC4 chain A
# Processing 3QC4 chain B
# Processing 3QC9 chain A
# Processing 3QC9 chain B
# Processing 3QC9 chain C
# Processing 3QC9 chain D
# Processing 3QCQ chain A
# Processing 3QCS chain A
# Processing 3QCX chain A
# Processing 3QCY chain A
# Processing 3QD0 chain A
# Processing 3QD3 chain A
# Processing 3QD4 chain A
# Processing 3QF9 chain A
# Processing 3QFV chain A
# Processing 3QFV chain B
# Processing 3QGW chain A
# Processing 3QGW chain B
# Processing 3QGY chain A
# Processing 3QGY chain B
# Processing 3QHR chain A
# Processing 3QHR chain C
# Processing 3QHW chain A
# Processing 3QHW chain C
# Processing 3QKK chain A
# Processing 3QKL chain A
# Processing 3QKM chain A
# Processing 3QL8 chain A
# Processing 3QLF chain A
# Processing 3QLF chain B
# Processing 3QLG chain A
# Processing 3QLG chain B
# Processing 3QQF chain A
# Processing 3QQG chain A
# Processing 3QQH chain A
# Processing 3QQJ chain A
# Processing 3QQK chain A
# Processing 3QQL chain A
# Processing 3QQU chain A
# Processing 3QQU chain B
# Processing 3QQU chain C
# Processing 3QQU chain D
# Processing 3QRI chain A
# Processing 3QRI chain B
# Processing 3QRJ chain A
# Processing 3QRJ chain B
# Processing 3QRK chain A
# Processing 3QRT chain A
# Processing 3QRU chain A
# Processing 3QTI chain A
# Processing 3QTI chain B
# Processing 3QTQ chain A
# Processing 3QTR chain A
# Processing 3QTS chain A
# Processing 3QTU chain A
# Processing 3QTW chain A
# Processing 3QTX chain A
# Processing 3QTZ chain A
# Processing 3QU0 chain A
# Processing 3QUD chain A
# Processing 3QUE chain A
# Processing 3QUP chain A
# Processing 3QWJ chain A
# Processing 3QWK chain A
# Processing 3QX2 chain A
# Processing 3QX4 chain A
# Processing 3QXO chain A
# Processing 3QXP chain A
# Processing 3QYW chain A
# Processing 3QYZ chain A
# Processing 3QZF chain A
# Processing 3QZG chain A
# Processing 3QZH chain A
# Processing 3QZI chain A
# Processing 3R00 chain A
# Processing 3R01 chain A
# Processing 3R02 chain A
# Processing 3R04 chain A
# Processing 3R0T chain A
# Processing 3R1N chain A
# Processing 3R1Q chain A
# Processing 3R1S chain A
# Processing 3R1Y chain A
# Processing 3R21 chain A
# Processing 3R22 chain A
# Processing 3R28 chain A
# Processing 3R2B chain A
# Processing 3R2B chain B
# Processing 3R2Y chain A
# Processing 3R30 chain A
# Processing 3R6X chain A
# Processing 3R71 chain A
# Processing 3R73 chain A
# Processing 3R7E chain A
# Processing 3R7I chain A
# Processing 3R7O chain A
# Processing 3R7U chain A
# Processing 3R7V chain A
# Processing 3R7Y chain A
# Processing 3R83 chain A
# Processing 3R8L chain A
# Processing 3R8M chain A
# Processing 3R8P chain A
# Processing 3R8U chain A
# Processing 3R8V chain A
# Processing 3R8Z chain A
# Processing 3R9D chain A
# Processing 3R9H chain A
# Processing 3R9N chain A
# Processing 3R9O chain A
# Processing 3RAH chain A
# Processing 3RAI chain A
# Processing 3RAK chain A
# Processing 3RAL chain A
# Processing 3RAW chain A
# Processing 3RAW chain B
# Processing 3RCD chain A
# Processing 3RCD chain C
# Processing 3RCJ chain A
# Processing 3REP chain A
# Processing 3RGF chain A
# Processing 3RHK chain A
# Processing 3RHK chain B
# Processing 3RHX chain A
# Processing 3RHX chain B
# Processing 3RI1 chain A
# Processing 3RI1 chain B
# Processing 3RIN chain A
# Processing 3RJC chain A
# Processing 3RK5 chain A
# Processing 3RK7 chain A
# Processing 3RK9 chain A
# Processing 3RKB chain A
# Processing 3RM6 chain A
# Processing 3RM7 chain A
# Processing 3RMF chain A
# Processing 3RNI chain A
# Processing 3ROC chain A
# Processing 3ROY chain A
# Processing 3RPO chain A
# Processing 3RPR chain A
# Processing 3RPS chain A
# Processing 3RPV chain A
# Processing 3RPY chain A
# Processing 3RTP chain A
# Processing 3RVG chain A
# Processing 3RWP chain A
# Processing 3RWQ chain A
# Processing 3RZB chain A
# Processing 3RZF chain A
# Processing 3S00 chain A
# Processing 3S0O chain A
# Processing 3S1H chain A
# Processing 3S2P chain A
# Processing 3S3I chain A
# Processing 3S4Q chain A
# Processing 3S95 chain A
# Processing 3S95 chain B
# Processing 3SA0 chain A
# Processing 3SAY chain A
# Processing 3SAY chain B
# Processing 3SC1 chain A
# Processing 3SD0 chain A
# Processing 3SD0 chain B
# Processing 3SDJ chain A
# Processing 3SDJ chain B
# Processing 3SDJ chain C
# Processing 3SDJ chain D
# Processing 3SDJ chain E
# Processing 3SDJ chain F
# Processing 3SDJ chain G
# Processing 3SDJ chain H
# Processing 3SDJ chain I
# Processing 3SDJ chain J
# Processing 3SDJ chain K
# Processing 3SDJ chain L
# Processing 3SDJ chain M
# Processing 3SDJ chain N
# Processing 3SHE chain A
# Processing 3SKC chain A
# Processing 3SKC chain B
# Processing 3SLS chain A
# Processing 3SLS chain B
# Processing 3SOA chain A
# Processing 3SOC chain A
# Processing 3SOC chain B
# Processing 3SQQ chain A
# Processing 3SRV chain A
# Processing 3SRV chain B
# Processing 3SVV chain A
# Processing 3SVV chain B
# Processing 3SW4 chain A
# Processing 3SW7 chain A
# Processing 3SX9 chain A
# Processing 3SXF chain A
# Processing 3SXR chain A
# Processing 3SXR chain B
# Processing 3SXS chain A
# Processing 3T3U chain A
# Processing 3T3V chain A
# Processing 3T8O chain A
# Processing 3T9I chain A
# Processing 3T9T chain A
# Processing 3TCP chain A
# Processing 3TCP chain B
# Processing 3TEI chain A
# Processing 3THB chain A
# Processing 3TI1 chain A
# Processing 3TIY chain A
# Processing 3TIZ chain A
# Processing 3TJC chain A
# Processing 3TJC chain B
# Processing 3TJD chain A
# Processing 3TJD chain B
# Processing 3TKH chain A
# Processing 3TKI chain A
# Processing 3TKU chain A
# Processing 3TKU chain B
# Processing 3TN8 chain A
# Processing 3TNH chain A
# Processing 3TNQ chain B
# Processing 3TNW chain A
# Processing 3TNW chain C
# Processing 3TT0 chain A
# Processing 3TT0 chain B
# Processing 3TTI chain A
# Processing 3TTJ chain A
# Processing 3TUB chain A
# Processing 3TUC chain A
# Processing 3TUD chain A
# Processing 3TV4 chain A
# Processing 3TV4 chain B
# Processing 3TV6 chain A
# Processing 3TV6 chain B
# Processing 3TV7 chain A
# Processing 3TV7 chain B
# Processing 3TV7 chain C
# Processing 3TV7 chain D
# Processing 3TWJ chain A
# Processing 3TWJ chain C
# Processing 3TXO chain A
# Processing 3TZ7 chain A
# Processing 3TZ7 chain B
# Processing 3TZ8 chain A
# Processing 3TZ8 chain B
# Processing 3TZ9 chain A
# Processing 3TZ9 chain B
# Processing 3TZM chain A
# Processing 3U4U chain A
# Processing 3U6H chain A
# Processing 3U6I chain A
# Processing 3U6J chain A
# Processing 3U87 chain A
# Processing 3U87 chain B
# Processing 3U8W chain A
# Processing 3U9C chain A
# Processing 3U9C chain B
# Processing 3U9N chain A
# Processing 3UBD chain A
# Processing 3UE4 chain A
# Processing 3UE4 chain B
# Processing 3UG2 chain A
# Processing 3UGC chain A
# Processing 3UIB chain A
# Processing 3UIM chain A
# Processing 3UIX chain A
# Processing 3ULI chain A
# Processing 3UMW chain A
# Processing 3UMX chain A
# Processing 3UNJ chain A
# Processing 3UNK chain A
# Processing 3UNZ chain A
# Processing 3UNZ chain B
# Processing 3UO4 chain A
# Processing 3UO5 chain A
# Processing 3UO6 chain A
# Processing 3UO6 chain B
# Processing 3UOD chain A
# Processing 3UOH chain A
# Processing 3UOH chain B
# Processing 3UOJ chain A
# Processing 3UOJ chain B
# Processing 3UOK chain A
# Processing 3UOK chain B
# Processing 3UOL chain A
# Processing 3UOL chain B
# Processing 3UP2 chain A
# Processing 3UP7 chain A
# Processing 3UPX chain A
# Processing 3UPZ chain A
# Processing 3UQF chain A
# Processing 3UQF chain B
# Processing 3UQG chain A
# Processing 3UQG chain B
# Processing 3UTO chain B
# Processing 3UVP chain A
# Processing 3UVQ chain A
# Processing 3UVR chain A
# Processing 3UYT chain A
# Processing 3UYT chain B
# Processing 3UYT chain C
# Processing 3UYT chain D
# Processing 3UZP chain A
# Processing 3UZP chain B
# Processing 3V01 chain A
# Processing 3V04 chain A
# Processing 3V3V chain A
# Processing 3V51 chain A
# Processing 3V5J chain A
# Processing 3V5J chain B
# Processing 3V5L chain A
# Processing 3V5L chain B
# Processing 3V5L chain C
# Processing 3V5L chain D
# Processing 3V5P chain A
# Processing 3V5Q chain A
# Processing 3V5Q chain B
# Processing 3V5T chain A
# Processing 3V5W chain A
# Processing 3V6R chain A
# Processing 3V6R chain B
# Processing 3V6S chain A
# Processing 3V6S chain B
# Processing 3V8S chain A
# Processing 3V8S chain B
# Processing 3V8S chain C
# Processing 3V8S chain D
# Processing 3V8T chain A
# Processing 3V8T chain B
# Processing 3V8W chain A
# Processing 3V8W chain B
# Processing 3VAP chain A
# Processing 3VBQ chain A
# Processing 3VBT chain A
# Processing 3VBV chain A
# Processing 3VBW chain A
# Processing 3VBX chain A
# Processing 3VBY chain A
# Processing 3VC4 chain A
# Processing 3VF8 chain A
# Processing 3VF9 chain A
# Processing 3VHE chain A
# Processing 3VHK chain A
# Processing 3VID chain A
# Processing 3VJN chain A
# Processing 3VJO chain A
# Processing 3VN9 chain A
# Processing 3VNT chain A
# Processing 3VO3 chain A
# Processing 3VQH chain A
# Processing 3VQU chain A
# Processing 3VRY chain A
# Processing 3VRY chain B
# Processing 3VRZ chain A
# Processing 3VRZ chain B
# Processing 3VS0 chain A
# Processing 3VS0 chain B
# Processing 3VS1 chain A
# Processing 3VS1 chain B
# Processing 3VS2 chain A
# Processing 3VS2 chain B
# Processing 3VS3 chain A
# Processing 3VS3 chain B
# Processing 3VS4 chain A
# Processing 3VS4 chain B
# Processing 3VS5 chain A
# Processing 3VS5 chain B
# Processing 3VS6 chain A
# Processing 3VS6 chain B
# Processing 3VS7 chain A
# Processing 3VS7 chain B
# Processing 3VVH chain A
# Processing 3VVH chain B
# Processing 3VVH chain C
# Processing 3VW6 chain A
# Processing 3VW6 chain B
# Processing 3VW8 chain A
# Processing 3W10 chain A
# Processing 3W16 chain A
# Processing 3W18 chain A
# Processing 3W18 chain B
# Processing 3W1F chain A
# Processing 3W2C chain A
# Processing 3W2C chain C
# Processing 3W2C chain E
# Processing 3W2C chain G
# Processing 3W2O chain A
# Processing 3W2P chain A
# Processing 3W2Q chain A
# Processing 3W2R chain A
# Processing 3W2S chain A
# Processing 3W32 chain A
# Processing 3W33 chain A
# Processing 3W55 chain A
# Processing 3W8L chain B
# Processing 3W8Q chain A
# Processing 3WAR chain A
# Processing 3WBL chain A
# Processing 3WE4 chain A
# Processing 3WE8 chain A
# Processing 3WF5 chain A
# Processing 3WF6 chain A
# Processing 3WF7 chain A
# Processing 3WF8 chain A
# Processing 3WF9 chain A
# Processing 3WI6 chain A
# Processing 3WI6 chain B
# Processing 3WI6 chain C
# Processing 3WI6 chain D
# Processing 3WI6 chain E
# Processing 3WI6 chain F
# Processing 3WIG chain A
# Processing 3WIK chain A
# Processing 3WIL chain A
# Processing 3WOW chain A
# Processing 3WYX chain A
# Processing 3WYY chain A
# Processing 3WZD chain A
# Processing 3WZE chain A
# Processing 3WZJ chain A
# Processing 3WZK chain A
# Processing 3WZU chain A
# Processing 3X2U chain A
# Processing 3X2V chain A
# Processing 3X2W chain A
# Processing 3ZBF chain A
# Processing 3ZBX chain A
# Processing 3ZC5 chain A
# Processing 3ZC6 chain A
# Processing 3ZC6 chain B
# Processing 3ZC6 chain C
# Processing 3ZC6 chain D
# Processing 3ZCL chain A
# Processing 3ZDI chain A
# Processing 3ZDU chain A
# Processing 3ZEP chain A
# Processing 3ZEP chain B
# Processing 3ZEP chain C
# Processing 3ZEP chain D
# Processing 3ZEW chain A
# Processing 3ZEW chain B
# Processing 3ZH8 chain A
# Processing 3ZH8 chain B
# Processing 3ZH8 chain C
# Processing 3ZLS chain A
# Processing 3ZLW chain A
# Processing 3ZLX chain A
# Processing 3ZLY chain A
# Processing 3ZM4 chain A
# Processing 3ZMM chain A
# Processing 3ZMM chain B
# Processing 3ZO1 chain A
# Processing 3ZO2 chain A
# Processing 3ZO3 chain A
# Processing 3ZO4 chain A
# Processing 3ZON chain A
# Processing 3ZOS chain A
# Processing 3ZOS chain B
# Processing 3ZRK chain A
# Processing 3ZRK chain B
# Processing 3ZRL chain A
# Processing 3ZRL chain B
# Processing 3ZRM chain A
# Processing 3ZRM chain B
# Processing 3ZS5 chain A
# Processing 3ZSG chain A
# Processing 3ZSH chain A
# Processing 3ZSI chain A
# Processing 3ZTX chain A
# Processing 3ZTX chain B
# Processing 3ZXT chain A
# Processing 3ZXT chain B
# Processing 3ZXT chain C
# Processing 3ZXT chain D
# Processing 3ZXZ chain A
# Processing 3ZYA chain A
# Processing 3ZZE chain A
# Processing 4A06 chain A
# Processing 4A07 chain A
# Processing 4A4L chain A
# Processing 4A4O chain A
# Processing 4A4X chain A
# Processing 4A7C chain A
# Processing 4A9R chain A
# Processing 4A9S chain A
# Processing 4A9T chain A
# Processing 4A9U chain A
# Processing 4A9Y chain A
# Processing 4AA0 chain A
# Processing 4AA4 chain A
# Processing 4AA5 chain A
# Processing 4AAA chain A
# Processing 4AAC chain A
# Processing 4ACC chain A
# Processing 4ACC chain B
# Processing 4ACD chain A
# Processing 4ACD chain B
# Processing 4ACG chain A
# Processing 4ACG chain B
# Processing 4ACH chain A
# Processing 4ACH chain B
# Processing 4ACM chain A
# Processing 4AF3 chain A
# Processing 4AFE chain A
# Processing 4AFJ chain A
# Processing 4AFJ chain B
# Processing 4AG8 chain A
# Processing 4AGC chain A
# Processing 4AGD chain A
# Processing 4AGU chain A
# Processing 4AGU chain B
# Processing 4AGU chain C
# Processing 4AGW chain A
# Processing 4AGW chain B
# Processing 4ALU chain A
# Processing 4ALV chain A
# Processing 4ALW chain A
# Processing 4AN2 chain A
# Processing 4AN3 chain A
# Processing 4AN9 chain A
# Processing 4ANB chain A
# Processing 4ANM chain A
# Processing 4ANQ chain A
# Processing 4ANS chain A
# Processing 4AOI chain A
# Processing 4AOJ chain A
# Processing 4AOJ chain B
# Processing 4AOJ chain C
# Processing 4AOT chain A
# Processing 4AOT chain B
# Processing 4AP7 chain A
# Processing 4APP chain A
# Processing 4AQC chain A
# Processing 4AQC chain B
# Processing 4ARK chain A
# Processing 4AS0 chain A
# Processing 4ASD chain A
# Processing 4ASE chain A
# Processing 4ASX chain A
# Processing 4ASX chain B
# Processing 4AT3 chain A
# Processing 4AT4 chain A
# Processing 4AT5 chain A
# Processing 4AU8 chain A
# Processing 4AU8 chain B
# Processing 4AUA chain A
# Processing 4AW0 chain A
# Processing 4AW1 chain A
# Processing 4AW2 chain A
# Processing 4AW5 chain A
# Processing 4AWI chain A
# Processing 4AXA chain A
# Processing 4AZE chain A
# Processing 4AZE chain B
# Processing 4AZE chain C
# Processing 4AZF chain A
# Processing 4B0G chain A
# Processing 4B6L chain A
# Processing 4B7T chain A
# Processing 4B8L chain A
# Processing 4B8M chain A
# Processing 4B8M chain B
# Processing 4B99 chain A
# Processing 4B9D chain A
# Processing 4B9D chain B
# Processing 4BB4 chain A
# Processing 4BBE chain A
# Processing 4BBE chain B
# Processing 4BBE chain C
# Processing 4BBE chain D
# Processing 4BBF chain A
# Processing 4BBF chain B
# Processing 4BBF chain C
# Processing 4BBF chain D
# Processing 4BBM chain A
# Processing 4BBM chain B
# Processing 4BC6 chain A
# Processing 4BCF chain A
# Processing 4BCG chain A
# Processing 4BCH chain A
# Processing 4BCI chain A
# Processing 4BCJ chain A
# Processing 4BCK chain A
# Processing 4BCK chain C
# Processing 4BCM chain A
# Processing 4BCM chain C
# Processing 4BCN chain A
# Processing 4BCN chain C
# Processing 4BCO chain A
# Processing 4BCO chain C
# Processing 4BCP chain A
# Processing 4BCP chain C
# Processing 4BCQ chain A
# Processing 4BCQ chain C
# Processing 4BDA chain A
# Processing 4BDB chain A
# Processing 4BDC chain A
# Processing 4BDD chain A
# Processing 4BDE chain A
# Processing 4BDF chain A
# Processing 4BDG chain A
# Processing 4BDH chain A
# Processing 4BDI chain A
# Processing 4BDJ chain A
# Processing 4BDK chain A
# Processing 4BF2 chain A
# Processing 4BF2 chain B
# Processing 4BFM chain A
# Processing 4BGG chain A
# Processing 4BGG chain B
# Processing 4BGG chain C
# Processing 4BGG chain D
# Processing 4BGH chain A
# Processing 4BGQ chain A
# Processing 4BHN chain A
# Processing 4BHN chain B
# Processing 4BHZ chain A
# Processing 4BI0 chain A
# Processing 4BI1 chain A
# Processing 4BI2 chain A
# Processing 4BIB chain A
# Processing 4BIB chain B
# Processing 4BIC chain A
# Processing 4BID chain A
# Processing 4BID chain B
# Processing 4BIE chain A
# Processing 4BIE chain B
# Processing 4BKJ chain A
# Processing 4BKJ chain B
# Processing 4BKY chain A
