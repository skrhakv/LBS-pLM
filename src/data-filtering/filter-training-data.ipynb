# %% [markdown]
# # Overlap
# Some sequences from the training data can significantly overlap with data from the kinases dataset. Let's fix this data leakage.

# %% [markdown]
# ## Prepare data for mmseqs2
# Extract sequences from the training data and from the kinases data

# %%
# Read the training data sequences and input them into a .fasta file
import csv 
with open('/home/vit/Projects/LBS-pLM/data/full-LIGYSIS/full-train.txt', 'r') as f:
    reader = csv.reader(f, delimiter=';')
    with open('/home/vit/Projects/LBS-pLM/data/filtering/sequences.fasta', 'w') as fasta_file:
        for row in reader:
            seq_id = row[0]
            sequence = row[4]
            fasta_file.write(f'>{seq_id}-TRAIN\n{sequence}\n')

# %% [markdown]
# ### REMARK
# We manually removed:
# ```
# 6M11,A
# 6M11,B
# 6M12,A
# 6M12,B
# 6M13,A
# 6M13,B
# ```
# from `kinase_pdb_chain_list.csv`.

# %%
# Read each PDB ID, take the sequence from the MMCIF file and input it into a .fasta file
CIF_FILES_PATH = '/home/vit/Projects/deeplife-project/data/cif_files'

mapping = {'Aba': 'A', 'Ace': 'X', 'Acr': 'X', 'Ala': 'A', 'Aly': 'K', 'Arg': 'R', 'Asn': 'N', 'Asp': 'D', 'Cas': 'C',
           'Ccs': 'C', 'Cme': 'C', 'Csd': 'C', 'Cso': 'C', 'Csx': 'C', 'Cys': 'C', 'Dal': 'A', 'Dbb': 'T', 'Dbu': 'T',
           'Dha': 'S', 'Gln': 'Q', 'Glu': 'E', 'Gly': 'G', 'Glz': 'G', 'His': 'H', 'Hse': 'S', 'Ile': 'I', 'Leu': 'L',
           'Llp': 'K', 'Lys': 'K', 'Men': 'N', 'Met': 'M', 'Mly': 'K', 'Mse': 'M', 'Nh2': 'X', 'Nle': 'L', 'Ocs': 'C',
           'Pca': 'E', 'Phe': 'F', 'Pro': 'P', 'Ptr': 'Y', 'Sep': 'S', 'Ser': 'S', 'Thr': 'T', 'Tih': 'A', 'Tpo': 'T',
           'Trp': 'W', 'Tyr': 'Y', 'Unk': 'X', 'Val': 'V', 'Ycm': 'C', 'Sec': 'U', 'Pyl': 'O', 'Mhs': 'H', 'Snm': 'S',
           'Mis': 'S', 'Seb': 'S', 'Hic': 'H', 'Fme': 'M', 'Asb': 'D', 'Sah': 'C', 'Smc': 'C', 'Tpq': 'Y', 'Onl': 'X',
           'Tox': 'W', '5x8': 'X', 'Ddz': 'A'}


def three_to_one(three_letter_code):
    if three_letter_code[0].upper() + three_letter_code[1:].lower() not in mapping:
        return 'X'
    return mapping[three_letter_code[0].upper() + three_letter_code[1:].lower()]

def get_sequence(pdb_id: str, chain_id: str) -> str:
    """
    Get the amino acid sequence of a specific chain from a PDB structure.
    """
    import biotite.database.rcsb as rcsb
    import biotite.structure.io.pdbx as pdbx
    from biotite.structure.io.pdbx import get_structure
    from biotite.structure import get_residues

    cif_file_path = rcsb.fetch(pdb_id, "cif", CIF_FILES_PATH)
    cif_file = pdbx.CIFFile.read(cif_file_path)
    
    protein = get_structure(cif_file, model=1)
    protein = protein[(protein.atom_name == "CA") 
                        & (protein.element == "C") 
                        & (protein.chain_id == chain_id) ]
    _, residue_types = get_residues(protein)

    sequence = ''
    for i in range(len(residue_types)):
        amino_acid = three_to_one(residue_types[i])

        sequence += amino_acid

    return sequence

skip = True
with open('/home/vit/Projects/LBS-pLM/data/kinase_pdb_chain_list.csv', 'r') as f:
    reader = csv.reader(f, delimiter=',')
    next(reader)  # Skip header
    with open('/home/vit/Projects/LBS-pLM/data/filtering/sequences.fasta', 'a') as fasta_file:
        for row in reader:
            pdb_id = row[0]
            chain_id = row[1]

            if pdb_id  == '6T28':  # Skip problematic structure
                skip = False
                continue
            if skip:
                continue

            print(f'Processing {pdb_id} chain {chain_id}')
            try:
                sequence = get_sequence(pdb_id, chain_id)
            except Exception as e:
                print(f'Error processing {pdb_id} chain {chain_id}: {e}')
                continue
            fasta_file.write(f'>{pdb_id}{chain_id}-TEST\n{sequence}\n')
# Out:
# Processing 6T29 chain A
# Error processing 6T29 chain A: index 0 is out of bounds for axis 0 with size 0
# Processing 6T2W chain A
# Processing 6T41 chain A
# Processing 6T6A chain A
# Processing 6T6A chain B
# Processing 6T6A chain C
# Processing 6T6D chain A
# Processing 6T6D chain B
# Processing 6T6D chain C
# Processing 6T6D chain D
# Processing 6T6F chain A
# Processing 6T6F chain B
# Processing 6T8N chain A
# Processing 6T8N chain B
# Processing 6T8X chain A
# Processing 6T8X chain B
# Processing 6T8X chain C
# Processing 6T8X chain D
# Processing 6T8X chain E
# Processing 6T8X chain F
# Processing 6TCA chain B
# Processing 6TCA chain D
# Processing 6TCA chain F
# Processing 6TCA chain H
# Processing 6TCU chain A
# Processing 6TD3 chain B
# Processing 6TD3 chain E
# Processing 6TD3 chain H
# Processing 6TE2 chain A
# Processing 6TEI chain A
# Processing 6TEI chain B
# Processing 6TEW chain A
# Processing 6TFP chain A
# Processing 6TFP chain B
# Processing 6TFP chain C
# Processing 6TFP chain D
# Processing 6TFP chain E
# Processing 6TFU chain A
# Processing 6TFU chain B
# Processing 6TFV chain A
# Processing 6TFV chain B
# Processing 6TFW chain A
# Processing 6TFW chain B
# Processing 6TFY chain A
# Processing 6TFY chain B
# Processing 6TFZ chain A
# Processing 6TFZ chain B
# Processing 6TG0 chain A
# Processing 6TG0 chain B
# Processing 6TG1 chain A
# Processing 6TG1 chain B
# Processing 6TGU chain A
# Processing 6THW chain A
# Processing 6THW chain B
# Processing 6THX chain A
# Processing 6THX chain B
# Processing 6THZ chain A
# Processing 6THZ chain B
# Processing 6TI8 chain A
# Processing 6TI8 chain B
# Processing 6TI8 chain C
# Processing 6TI8 chain D
# Processing 6TIA chain A
# Processing 6TIA chain B
# Processing 6TLL chain A
# Processing 6TLO chain A
# Processing 6TLP chain A
# Processing 6TLR chain A
# Processing 6TLS chain A
# Processing 6TLU chain A
# Error processing 6TLU chain A: index 0 is out of bounds for axis 0 with size 0
# Processing 6TLV chain A
# Processing 6TLW chain A
# Processing 6TN8 chain A
# Processing 6TN9 chain A
# Processing 6TNB chain A
# Processing 6TNC chain A
# Processing 6TND chain A
# Processing 6TPA chain A
# Processing 6TPD chain A
# Processing 6TPE chain A
# Processing 6TPE chain B
# Processing 6TPF chain A
# Processing 6TPF chain B
# Processing 6TSZ chain U
# Processing 6TU9 chain A
# Processing 6TU9 chain B
# Processing 6TW2 chain E
# Processing 6TY4 chain A
# Processing 6TY4 chain B
# Processing 6U0K chain A
# Processing 6U0K chain B
# Processing 6U2G chain A
# Processing 6U2G chain B
# Processing 6U2H chain C
# Processing 6U2H chain D
# Processing 6U5L chain A
# Processing 6U6A chain A
# Processing 6U7C chain A
# Processing 6UBW chain A
# Processing 6UIP chain A
# Processing 6UIP chain B
# Processing 6UIP chain C
# Processing 6UL8 chain A
# Processing 6UL8 chain B
# Processing 6UMW chain A
# Processing 6UNP chain A
# Processing 6UNP chain B
# Processing 6UNQ chain A
# Processing 6UNR chain A
# Processing 6UNS chain A
# Processing 6UNS chain B
# Processing 6URC chain A
# Processing 6URC chain B
# Processing 6UUO chain A
# Processing 6UUO chain B
# Processing 6UWY chain A
# Processing 6UWY chain B
# Processing 6UWY chain C
# Processing 6UWY chain D
# Processing 6UYA chain A
# Processing 6UYA chain B
# Processing 6UYA chain C
# Processing 6UYA chain D
# Processing 6V2U chain A
# Processing 6V2U chain B
# Processing 6V2W chain A
# Processing 6V2W chain B
# Processing 6V34 chain A
# Processing 6V34 chain B
# Processing 6V5N chain A
# Processing 6V5N chain B
# Processing 6V5N chain C
# Processing 6V5N chain D
# Processing 6V5P chain A
# Processing 6V5P chain B
# Processing 6V5P chain C
# Processing 6V5P chain D
# Processing 6V66 chain A
# Processing 6V66 chain B
# Processing 6V66 chain C
# Processing 6V66 chain D
# Processing 6V6K chain A
# Processing 6V6K chain B
# Processing 6V6K chain C
# Processing 6V6K chain D
# Processing 6V6K chain E
# Processing 6V6K chain F
# Processing 6V6K chain G
# Processing 6V6K chain H
# Processing 6V6L chain A
# Processing 6V6O chain A
# Processing 6V6O chain B
# Processing 6V6O chain C
# Processing 6V6O chain D
# Processing 6V6O chain E
# Processing 6V6O chain F
# Processing 6V6O chain G
# Processing 6V6O chain H
# Processing 6V6Q chain A
# Processing 6V6Q chain B
# Processing 6V6Q chain C
# Processing 6V6Q chain D
# Processing 6V9C chain A
# Processing 6VGL chain A
# Processing 6VGL chain B
# Processing 6VGL chain C
# Processing 6VGL chain D
# Processing 6VH4 chain A
# Processing 6VHG chain A
# Processing 6VHN chain A
# Processing 6VHP chain A
# Processing 6VN8 chain A
# Processing 6VN8 chain B
# Processing 6VNB chain A
# Processing 6VNB chain B
# Processing 6VNC chain A
# Processing 6VNC chain B
# Processing 6VNE chain A
# Processing 6VNE chain B
# Processing 6VNF chain A
# Processing 6VNF chain B
# Processing 6VNG chain A
# Processing 6VNG chain B
# Processing 6VNH chain A
# Processing 6VNH chain B
# Processing 6VNI chain A
# Processing 6VNI chain B
# Processing 6VNJ chain A
# Processing 6VNJ chain B
# Processing 6VNK chain A
# Processing 6VNK chain B
# Processing 6VNK chain C
# Processing 6VNK chain D
# Processing 6VNL chain A
# Processing 6VNL chain B
# Processing 6VNL chain C
# Processing 6VNL chain D
# Processing 6VNM chain A
# Processing 6VNM chain B
# Processing 6VNS chain A
# Processing 6VNV chain A
# Processing 6VNX chain A
# Processing 6VNY chain A
# Processing 6VOV chain A
# Processing 6VOV chain B
# Processing 6VPG chain A
# Processing 6VPH chain A
# Processing 6VPI chain A
# Processing 6VPJ chain A
# Processing 6VPL chain A
# Processing 6VPL chain B
# Processing 6VPM chain A
# Processing 6VPM chain B
# Processing 6VQL chain A
# Processing 6VQL chain B
# Processing 6VQL chain C
# Processing 6VQL chain D
# Processing 6VQM chain A
# Processing 6VQM chain B
# Processing 6VRE chain A
# Processing 6VRE chain B
# Processing 6VRF chain A
# Processing 6VRF chain B
# Processing 6VRU chain A
# Processing 6VRV chain A
# Processing 6VS3 chain A
# Processing 6VS3 chain B
# Processing 6VSN chain A
# Processing 6VSN chain B
# Processing 6VSN chain C
# Processing 6VSN chain D
# Processing 6VVG chain A
# Processing 6VVG chain B
# Processing 6VXQ chain A
# Processing 6VXR chain A
# Processing 6VXU chain A
# Processing 6VXU chain B
# Processing 6VXU chain C
# Processing 6VXU chain D
# Processing 6VZH chain B
# Processing 6VZH chain D
# Processing 6W06 chain A
# Processing 6W07 chain A
# Processing 6W39 chain A
# Processing 6W39 chain B
# Processing 6W3A chain A
# Processing 6W3A chain B
# Processing 6W3E chain A
# Processing 6W3E chain B
# Processing 6W3K chain A
# Processing 6W7O chain A
# Processing 6W7O chain B
# Processing 6W8I chain C
# Processing 6W8L chain A
# Processing 6W9E chain A
# Processing 6WA2 chain A
# Processing 6WA2 chain B
# Processing 6WA2 chain C
# Processing 6WA2 chain D
# Processing 6WAK chain A
# Processing 6WAK chain B
# Processing 6WAK chain C
# Processing 6WAK chain D
# Processing 6WIW chain A
# Processing 6WIW chain B
# Processing 6WPP chain A
# Processing 6WPP chain B
# Processing 6WQX chain C
# Processing 6WQX chain D
# Processing 6WTN chain A
# Processing 6WTO chain A
# Processing 6WTP chain A
# Processing 6WTQ chain A
# Processing 6WXJ chain A
# Processing 6WXN chain B
# Processing 6WXN chain C
# Processing 6WXN chain D
# Processing 6X3N chain A
# Processing 6X3O chain A
# Processing 6X3O chain B
# Processing 6X3P chain A
# Processing 6X5G chain A
# Processing 6X8E chain A
# Processing 6X8E chain B
# Processing 6X8F chain A
# Processing 6X8F chain C
# Processing 6X8G chain A
# Processing 6XBZ chain J
# Processing 6XD3 chain J
# Processing 6XDB chain A
# Processing 6XDD chain A
# Processing 6XDD chain B
# Processing 6XDF chain A
# Processing 6XE4 chain A
# Processing 6XFP chain A
# Processing 6XI8 chain A
# Processing 6XIH chain A
# Processing 6XIH chain B
# Processing 6XJK chain A
# Processing 6XL4 chain A
# Processing 6XL4 chain B
# Processing 6XL4 chain D
# Processing 6XLO chain A
# Processing 6XLO chain B
# Processing 6XV9 chain A
# Processing 6XV9 chain B
# Processing 6XVA chain A
# Processing 6XVA chain B
# Processing 6XVB chain A
# Processing 6XVB chain B
# Processing 6XVJ chain A
# Processing 6XVK chain A
# Processing 6XX7 chain A
# Processing 6Y05 chain A
# Processing 6Y0A chain A
# Processing 6Y0B chain A
# Processing 6Y2O chain A
# Processing 6Y2U chain A
# Processing 6Y4T chain A
# Processing 6Y4U chain A
# Processing 6Y4V chain A
# Processing 6Y4W chain A
# Processing 6Y4X chain A
# Processing 6Y6F chain A
# Processing 6Y6H chain A
# Processing 6Y6V chain A
# Processing 6Y7W chain A
# Processing 6Y7X chain A
# Processing 6Y7Y chain A
# Processing 6Y7Z chain A
# Processing 6Y80 chain A
# Processing 6Y81 chain A
# Processing 6Y82 chain A
# Processing 6Y85 chain A
# Processing 6Y89 chain A
# Processing 6Y8C chain A
# Processing 6Y8H chain A
# Processing 6Y9R chain A
# Processing 6Y9S chain A
# Processing 6Y9S chain B
# Processing 6YA6 chain A
# Processing 6YA7 chain A
# Processing 6YA8 chain A
# Processing 6YAT chain A
# Processing 6YAT chain B
# Processing 6YCU chain A
# Processing 6YCW chain A
# Processing 6YF8 chain A
# Processing 6YF8 chain B
# Processing 6YF8 chain C
# Processing 6YF8 chain D
# Processing 6YG2 chain A
# Processing 6YG3 chain A
# Processing 6YG4 chain A
# Processing 6YG5 chain A
# Processing 6YG6 chain A
# Processing 6YG6 chain B
# Processing 6YG7 chain A
# Processing 6YG7 chain B
# Processing 6YI8 chain A
# Processing 6YI8 chain B
# Processing 6YID chain A
# Processing 6YID chain B
# Processing 6YID chain C
# Processing 6YID chain D
# Processing 6YJC chain A
# Processing 6YK7 chain A
# Processing 6YKD chain A
# Processing 6YKY chain A
# Processing 6YKY chain B
# Processing 6YKY chain C
# Processing 6YKY chain D
# Processing 6YL1 chain A
# Processing 6YLC chain A
# Processing 6YLC chain B
# Processing 6YLC chain C
# Processing 6YLC chain D
# Processing 6YLK chain A
# Processing 6YLL chain A
# Processing 6YNA chain A
# Processing 6YNB chain A
# Processing 6YNC chain A
# Processing 6YNR chain A
# Processing 6YNT chain A
# Processing 6YOJ chain A
# Processing 6YOT chain A
# Processing 6YOU chain A
# Processing 6YPG chain A
# Processing 6YPH chain A
# Processing 6YPH chain B
# Processing 6YPJ chain A
# Processing 6YPN chain B
# Processing 6YPP chain A
# Processing 6YPS chain A
# Processing 6YQ1 chain A
# Processing 6YQ1 chain B
# Processing 6YQ1 chain C
# Processing 6YQ1 chain D
# Processing 6YQI chain A
# Processing 6YQJ chain A
# Processing 6YQK chain A
# Processing 6YR9 chain A
# Processing 6YR9 chain B
# Processing 6YR9 chain C
# Processing 6YR9 chain D
# Processing 6YT6 chain A
# Processing 6YT6 chain B
# Processing 6YTA chain A
# Processing 6YTD chain A
# Processing 6YTE chain C
# Processing 6YTG chain A
# Processing 6YTI chain A
# Processing 6YTW chain A
# Processing 6YTW chain B
# Processing 6YTY chain A
# Processing 6YU1 chain A
# Error processing 6YU1 chain A: index 0 is out of bounds for axis 0 with size 0
# Processing 6YU1 chain C
# Error processing 6YU1 chain C: index 0 is out of bounds for axis 0 with size 0
# Processing 6YUL chain A
# Error processing 6YUL chain A: index 0 is out of bounds for axis 0 with size 0
# Processing 6YUL chain G
# Error processing 6YUL chain G: index 0 is out of bounds for axis 0 with size 0
# Processing 6YUM chain A
# Error processing 6YUM chain A: index 0 is out of bounds for axis 0 with size 0
# Processing 6YUM chain G
# Error processing 6YUM chain G: index 0 is out of bounds for axis 0 with size 0
# Processing 6YVS chain A
# Processing 6YVS chain B
# Processing 6YVS chain C
# Processing 6YVS chain D
# Processing 6YVY chain A
# Processing 6YVY chain B
# Processing 6YVY chain C
# Processing 6YVY chain D
# Processing 6YXV chain A
# Processing 6YXV chain B
# Processing 6YXV chain C
# Processing 6YXV chain D
# Processing 6YZ4 chain A
# Processing 6YZH chain A
# Processing 6Z08 chain A
# Processing 6Z19 chain B
# Processing 6Z1C chain A
# Processing 6Z1Q chain A
# Error processing 6Z1Q chain A: index 0 is out of bounds for axis 0 with size 0
# Processing 6Z1Q chain B
# Error processing 6Z1Q chain B: index 0 is out of bounds for axis 0 with size 0
# Processing 6Z1T chain A
# Error processing 6Z1T chain A: index 0 is out of bounds for axis 0 with size 0
# Processing 6Z1T chain B
# Error processing 6Z1T chain B: index 0 is out of bounds for axis 0 with size 0
# Processing 6Z2V chain A
# Processing 6Z36 chain A
# Processing 6Z36 chain B
# Processing 6Z45 chain A
# Processing 6Z4B chain A
# Processing 6Z4B chain B
# Processing 6Z4D chain A
# Processing 6Z4D chain B
# Processing 6Z4X chain B
# Processing 6Z4X chain E
# Processing 6Z4Y chain A
# Processing 6Z4Z chain A
# Processing 6Z4Z chain B
# Processing 6Z4Z chain C
# Processing 6Z50 chain A
# Processing 6Z51 chain A
# Processing 6Z52 chain A
# Processing 6Z52 chain B
# Processing 6Z53 chain A
# Processing 6Z54 chain A
# Processing 6Z55 chain A
# Processing 6Z55 chain B
# Processing 6Z56 chain A
# Processing 6Z57 chain A
# Processing 6Z58 chain A
# Processing 6Z59 chain A
# Processing 6Z5A chain A
# Processing 6Z5B chain A
# Processing 6Z5C chain A
# Processing 6Z5D chain A
# Processing 6Z5E chain A
# Processing 6Z83 chain A
# Error processing 6Z83 chain A: index 0 is out of bounds for axis 0 with size 0
# Processing 6Z83 chain B
# Error processing 6Z83 chain B: index 0 is out of bounds for axis 0 with size 0
# Processing 6Z84 chain A
# Error processing 6Z84 chain A: index 0 is out of bounds for axis 0 with size 0
# Processing 6Z84 chain B
# Error processing 6Z84 chain B: index 0 is out of bounds for axis 0 with size 0
# Processing 6ZC0 chain A
# Processing 6ZCP chain A
# Processing 6ZCQ chain A
# Processing 6ZCR chain A
# Processing 6ZCS chain A
# Processing 6ZCU chain A
# Processing 6ZCX chain A
# Processing 6ZCY chain A
# Processing 6ZGC chain A
# Processing 6ZGC chain B
# Processing 6ZGC chain C
# Processing 6ZGC chain D
# Processing 6ZIW chain I
# Processing 6ZJF chain A
# Processing 6ZLN chain A
# Processing 6ZN0 chain A
# Processing 6ZQS chain A
# Processing 6ZR5 chain A
# Processing 6ZR5 chain B
# Processing 6ZWP chain A
# Processing 6ZWR chain A
# Processing 7A1B chain A
# Processing 7A1Z chain A
# Processing 7A21 chain A
# Processing 7A21 chain B
# Processing 7A22 chain A
# Processing 7A2A chain A
# Processing 7A2A chain B
# Processing 7A2H chain A
# Processing 7A49 chain A
# Processing 7A49 chain B
# Processing 7A4B chain A
# Processing 7A4B chain B
# Processing 7A4C chain A
# Processing 7A4C chain B
# Processing 7A4O chain A
# Processing 7A4O chain B
# Processing 7A4Q chain A
# Processing 7A4R chain A
# Processing 7A4R chain B
# Processing 7A4S chain A
# Processing 7A4W chain A
# Processing 7A4W chain B
# Processing 7A4Z chain A
# Processing 7A51 chain A
# Processing 7A52 chain A
# Processing 7A52 chain B
# Processing 7A53 chain A
# Processing 7A53 chain B
# Processing 7A55 chain A
# Processing 7A55 chain B
# Processing 7A5B chain A
# Processing 7A5B chain B
# Processing 7A5D chain A
# Processing 7A5L chain A
# Processing 7A5N chain A
# Processing 7A5N chain B
# Processing 7A6I chain A
# Processing 7A6J chain A
# Processing 7A6J chain B
# Processing 7A6K chain A
# Processing 7A6K chain B
# Processing 7A6K chain C
# Processing 7A6K chain D
# Processing 7AAX chain A
# Processing 7AAY chain A
# Processing 7AAZ chain A
# Processing 7AB1 chain A
# Processing 7AB2 chain A
# Processing 7ACK chain A
# Processing 7ACK chain C
# Processing 7AEI chain A
# Processing 7AEM chain A
# Processing 7AH3 chain A
# Processing 7AH3 chain B
# Processing 7AJ2 chain A
# Processing 7AJ4 chain A
# Processing 7AJ5 chain A
# Processing 7AJ7 chain A
# Processing 7AJ8 chain A
# Processing 7AJA chain A
# Processing 7AJM chain A
# Processing 7AJM chain B
# Processing 7AJS chain A
# Processing 7AJS chain B
# Processing 7AJV chain A
# Processing 7AJV chain B
# Processing 7AJW chain A
# Processing 7AJY chain A
# Processing 7AJY chain B
# Processing 7AK2 chain A
# Processing 7AK2 chain B
# Processing 7AK3 chain A
# Processing 7AKA chain A
# Processing 7AKA chain B
# Processing 7AKB chain A
# Processing 7AKB chain B
# Processing 7AKE chain A
# Processing 7AKE chain B
# Processing 7AKF chain A
# Processing 7AKG chain A
# Processing 7AKH chain A
# Processing 7AKL chain A
# Processing 7AKM chain A
# Processing 7AKO chain A
# Processing 7AKO chain B
# Processing 7APF chain A
# Processing 7APF chain B
# Processing 7APG chain A
# Processing 7APG chain B
# Processing 7APG chain C
# Processing 7APG chain D
# Processing 7AT5 chain A
# Processing 7AT5 chain B
# Processing 7AT9 chain A
# Processing 7ATS chain A
# Processing 7ATU chain A
# Processing 7ATU chain B
# Processing 7ATU chain C
# Processing 7ATU chain D
# Processing 7ATV chain A
# Processing 7AUV chain A
# Processing 7AVQ chain A
# Processing 7AVX chain A
# Processing 7AVX chain B
# Processing 7AVY chain A
# Processing 7AVZ chain A
# Processing 7AW0 chain A
# Processing 7AW1 chain A
# Processing 7AW2 chain A
# Processing 7AW3 chain A
# Processing 7AW4 chain A
# Processing 7AW4 chain B
# Processing 7AX4 chain A
# Processing 7AX4 chain B
# Processing 7AXT chain A
# Processing 7AXV chain A
# Processing 7AXW chain A
# Processing 7AY9 chain A
# Processing 7AY9 chain B
# Processing 7AYA chain A
# Processing 7AYA chain B
# Processing 7AYH chain A
# Processing 7AYI chain A
# Processing 7AYM chain A
# Processing 7B30 chain A
# Processing 7B31 chain A
# Processing 7B32 chain A
# Processing 7B33 chain A
# Processing 7B34 chain A
# Processing 7B35 chain A
# Processing 7B35 chain B
# Processing 7B36 chain A
# Processing 7B36 chain C
# Processing 7B3M chain A
# Processing 7B3M chain B
# Processing 7B3Q chain A
# Processing 7B3T chain A
# Processing 7B3V chain A
# Processing 7B3W chain A
# Processing 7B3Z chain A
# Processing 7B40 chain A
# Processing 7B41 chain A
# Processing 7B42 chain A
# Processing 7B43 chain A
# Processing 7B43 chain B
# Processing 7B44 chain A
# Processing 7B56 chain B
# Processing 7B57 chain B
# Processing 7B5O chain J
# Processing 7B5Q chain J
# Processing 7B6F chain A
# Processing 7B7R chain A
# Processing 7B7R chain B
# Processing 7B7S chain A
# Processing 7B7S chain C
# Processing 7B85 chain A
# Processing 7B8H chain A
# Processing 7B8W chain A
# Processing 7B8W chain B
# Processing 7B8W chain C
# Processing 7B8W chain D
# Processing 7B94 chain A
# Processing 7B94 chain B
# Processing 7B9L chain A
# Processing 7B9L chain B
# Processing 7BAQ chain A
# Processing 7BAR chain A
# Processing 7BB0 chain A
# Processing 7BCM chain A
# Processing 7BCM chain B
# Processing 7BDO chain A
# Processing 7BDQ chain A
# Processing 7BE4 chain A
# Processing 7BE5 chain A
# Processing 7BE6 chain A
# Processing 7BJD chain A
# Processing 7BJE chain A
# Processing 7BJH chain A
# Processing 7BJJ chain A
# Processing 7BJM chain A
# Processing 7BJO chain A
# Processing 7BJR chain A
# Processing 7BJX chain A
# Processing 7BJX chain B
# Processing 7BK1 chain A
# Processing 7BK2 chain A
# Processing 7BK3 chain A
# Processing 7BKN chain A
# Processing 7BKO chain A
# Processing 7BMK chain A
# Processing 7BMK chain B
# Processing 7BTT chain A
# Processing 7BU4 chain A
# Processing 7C2V chain A
# Processing 7C2V chain B
# Processing 7C2V chain C
# Processing 7C2V chain D
# Processing 7C2W chain A
# Processing 7C2W chain B
# Processing 7C2W chain C
# Processing 7C2W chain D
# Processing 7C3G chain A
# Processing 7C3G chain B
# Processing 7C3N chain A
# Processing 7CBX chain A
# Processing 7CC2 chain A
# Processing 7CC2 chain B
# Processing 7CCU chain A
# Processing 7CCV chain A
# Processing 7CCW chain A
# Processing 7CHM chain A
# Processing 7CHN chain A
# Processing 7CHT chain A
# Processing 7CIL chain A
# Processing 7CJA chain A
# Processing 7CLH chain A
# Processing 7CMB chain A
# Processing 7CP3 chain A
# Processing 7CP4 chain A
# Processing 7CQE chain A
# Processing 7CQE chain C
# Processing 7CTV chain A
# Processing 7CTV chain B
# Processing 7CTX chain A
# Processing 7CTX chain B
# Processing 7D57 chain A
# Processing 7D57 chain B
# Processing 7D5O chain A
# Processing 7D5O chain B
# Processing 7DG4 chain A
# Processing 7DH3 chain A
# Processing 7DH9 chain A
# Processing 7DHC chain A
# Processing 7DHH chain A
# Processing 7DHK chain A
# Processing 7DHL chain A
# Processing 7DHN chain A
# Processing 7DHO chain A
# Processing 7DHV chain A
# Processing 7DJO chain A
# Processing 7DL6 chain A
# Processing 7DSY chain A
# Error processing 7DSY chain A: index 0 is out of bounds for axis 0 with size 0
# Processing 7DSY chain B
# Error processing 7DSY chain B: index 0 is out of bounds for axis 0 with size 0
# Processing 7DT2 chain A
# Processing 7DT2 chain B
# Processing 7DTS chain A
# Error processing 7DTS chain A: index 0 is out of bounds for axis 0 with size 0
# Processing 7DTS chain B
# Error processing 7DTS chain B: index 0 is out of bounds for axis 0 with size 0
# Processing 7DTZ chain A
# Processing 7DU8 chain A
# Processing 7DU8 chain B
# Processing 7DU9 chain A
# Processing 7DU9 chain B
# Processing 7DUA chain A
# Processing 7DUA chain B
# Processing 7DV6 chain A
# Processing 7DXL chain A
# Processing 7DXL chain B
# Processing 7E0Z chain A
# Processing 7E11 chain A
# Processing 7E12 chain A
# Processing 7EJV chain A
# Processing 7EJV chain B
# Processing 7ELW chain A
# Error processing 7ELW chain A: index 0 is out of bounds for axis 0 with size 0
# Processing 7ELW chain B
# Error processing 7ELW chain B: index 0 is out of bounds for axis 0 with size 0
# Processing 7ER2 chain A
# Processing 7F2X chain A
# Processing 7F3G chain A
# Processing 7F3G chain B
# Processing 7F3M chain A
# Processing 7F7W chain A
# Processing 7F7W chain B
# Processing 7FCZ chain A
# Processing 7FCZ chain B
# Processing 7FD0 chain A
# Processing 7FD0 chain B
# Processing 7FEH chain A
# Processing 7FHS chain A
# Processing 7FHS chain B
# Processing 7FHS chain C
# Processing 7FHS chain D
# Processing 7FHT chain A
# Processing 7FHT chain B
# Processing 7FHT chain C
# Processing 7FHT chain D
# Processing 7FIC chain A
# Processing 7JHG chain A
# Processing 7JNT chain A
# Processing 7JNT chain B
# Processing 7JNT chain C
# Processing 7JNT chain D
# Processing 7JNT chain E
# Processing 7JNT chain F
# Processing 7JNT chain G
# Processing 7JNT chain H
# Processing 7JOU chain A
# Processing 7JOV chain A
# Processing 7JOV chain B
# Processing 7JOV chain C
# Processing 7JOV chain D
# Processing 7JOV chain E
# Processing 7JOV chain F
# Processing 7JOV chain G
# Processing 7JOV chain H
# Processing 7JU5 chain A
# Processing 7JU5 chain B
# Processing 7JU6 chain A
# Processing 7JU6 chain B
# Processing 7JUQ chain B
# Processing 7JUQ chain C
# Processing 7JUR chain B
# Processing 7JUR chain C
# Processing 7JUS chain B
# Processing 7JUS chain C
# Processing 7JUT chain B
# Processing 7JUT chain C
# Processing 7JUU chain B
# Processing 7JUU chain C
# Processing 7JUV chain B
# Processing 7JUV chain C
# Processing 7JUW chain B
# Processing 7JUW chain C
# Processing 7JUX chain A
# Processing 7JUX chain C
# Processing 7JUY chain B
# Processing 7JUY chain C
# Processing 7JUZ chain A
# Processing 7JUZ chain C
# Processing 7JV0 chain A
# Processing 7JV0 chain C
# Processing 7JV1 chain C
# Processing 7JV1 chain D
# Processing 7JXH chain A
# Processing 7JXH chain B
# Processing 7JXH chain C
# Processing 7JXH chain D
# Processing 7JXH chain E
# Processing 7JXH chain F
# Processing 7JXH chain G
# Processing 7JXH chain H
# Processing 7JXI chain A
# Processing 7JXI chain B
# Processing 7JXI chain C
# Processing 7JXI chain D
# Processing 7JXK chain A
# Processing 7JXK chain B
# Processing 7JXK chain C
# Processing 7JXK chain D
# Processing 7JXK chain E
# Processing 7JXK chain F
# Processing 7JXL chain A
# Processing 7JXL chain B
# Processing 7JXL chain C
# Processing 7JXL chain D
# Processing 7JXM chain A
# Processing 7JXM chain B
# Processing 7JXM chain C
# Processing 7JXM chain D
# Processing 7JXP chain A
# Processing 7JXP chain B
# Processing 7JXP chain C
# Processing 7JXP chain D
# Processing 7JXP chain E
# Processing 7JXP chain F
# Processing 7JXQ chain A
# Processing 7JXQ chain B
# Processing 7JXQ chain C
# Processing 7JXQ chain D
# Processing 7JXW chain A
# Processing 7JXW chain B
# Processing 7JXW chain C
# Processing 7JXW chain D
# Processing 7JXX chain A
# Processing 7JXY chain A
# Processing 7JXY chain B
# Processing 7JY4 chain A
# Processing 7JYO chain A
# Processing 7JYQ chain A
# Processing 7JYR chain A
# Processing 7JYS chain A
# Processing 7JYT chain A
# Processing 7K0V chain A
# Processing 7K0V chain B
# Processing 7K0V chain C
# Processing 7K0V chain D
# Processing 7K1H chain A
# Processing 7K1H chain B
# Processing 7K1H chain C
# Processing 7K1H chain D
# Processing 7K1H chain E
# Processing 7K1H chain F
# Processing 7K1I chain A
# Processing 7K7L chain A
# Processing 7K7O chain A
# Processing 7K7O chain B
# Processing 7K7Q chain A
# Processing 7K7Q chain B
# Processing 7K7Z chain A
# Processing 7KAC chain A
# Processing 7KAC chain B
# Processing 7KHG chain A
# Processing 7KHJ chain A
# Processing 7KHJ chain B
# Processing 7KHK chain A
# Processing 7KHK chain B
# Processing 7KIA chain A
# Processing 7KIA chain B
# Processing 7KIE chain A
# Processing 7KIE chain B
# Processing 7KJA chain A
# Processing 7KJA chain B
# Processing 7KJC chain A
# Processing 7KJC chain B
# Processing 7KJS chain A
# Processing 7KL0 chain A
# Processing 7KL0 chain B
# Processing 7KP6 chain A
# Processing 7KP6 chain B
# Processing 7KPM chain A
# Processing 7KSI chain A
# Processing 7KSJ chain A
# Processing 7KSK chain A
# Processing 7KUE chain A
# Processing 7KX6 chain A
# Processing 7KX6 chain B
# Processing 7KX8 chain A
# Processing 7KX8 chain B
# Processing 7KXL chain A
# Processing 7KXM chain A
# Processing 7KXN chain A
# Processing 7KXO chain A
# Processing 7KXP chain A
# Processing 7KXQ chain A
# Processing 7KXW chain A
# Processing 7KXW chain B
# Processing 7KXZ chain A
# Processing 7KY0 chain A
# Processing 7KY0 chain B
# Processing 7KY0 chain C
# Processing 7KY0 chain D
# Processing 7L1X chain A
# Processing 7L24 chain A
# Processing 7L24 chain B
# Processing 7L24 chain C
# Processing 7L24 chain D
# Processing 7L25 chain A
# Processing 7L25 chain B
# Processing 7L26 chain A
# Processing 7L26 chain B
# Processing 7L26 chain C
# Processing 7L26 chain D
# Processing 7L5O chain A
# Processing 7L5P chain A
# Processing 7L5P chain B
# Processing 7LG8 chain A
# Processing 7LG8 chain B
# Processing 7LG8 chain C
# Processing 7LG8 chain D
# Processing 7LGS chain A
# Processing 7LGS chain B
# Processing 7LGS chain C
# Processing 7LGS chain D
# Processing 7LHT chain A
# Processing 7LHT chain B
# Processing 7LHW chain A
# Processing 7LI3 chain A
# Processing 7LI4 chain A
# Processing 7LL4 chain A
# Processing 7LL5 chain A
# Processing 7LQD chain A
# Processing 7LTX chain A
# Processing 7LTX chain B
# Processing 7LTX chain C
# Processing 7LTX chain D
# Processing 7LTY chain A
# Processing 7LTZ chain A
# Processing 7LV3 chain A
# Processing 7LV3 chain B
# Processing 7LVH chain A
# Processing 7LVH chain B
# Processing 7LVI chain A
# Processing 7LVI chain B
# Processing 7M0K chain A
# Processing 7M0K chain B
# Processing 7M0K chain C
# Processing 7M0K chain D
# Processing 7M0L chain A
# Processing 7M0L chain B
# Processing 7M0L chain C
# Processing 7M0L chain D
# Processing 7M0M chain A
# Processing 7M0M chain B
# Processing 7M0T chain A
# Processing 7M0T chain B
# Processing 7M0U chain A
# Processing 7M0U chain B
# Processing 7M0V chain A
# Processing 7M0V chain B
# Processing 7M0W chain A
# Processing 7M0W chain B
# Processing 7M0X chain A
# Processing 7M0X chain B
# Processing 7M0Y chain A
# Processing 7M0Y chain B
# Processing 7M0Z chain A
# Processing 7M0Z chain B
# Processing 7M2F chain A
# Processing 7M5Z chain A
# Processing 7M5Z chain B
# Processing 7M74 chain A
# Processing 7MCK chain A
# Processing 7MF0 chain A
# Error processing 7MF0 chain A: index 0 is out of bounds for axis 0 with size 0
# Processing 7MFC chain A
# Processing 7MFD chain B
# Processing 7MFF chain A
# Processing 7MFF chain B
# Processing 7MGJ chain A
# Processing 7MGJ chain B
# Processing 7MGJ chain C
# Processing 7MGJ chain D
# Processing 7MGK chain A
# Processing 7MGK chain B
# Processing 7MGK chain C
# Processing 7MGK chain D
# Processing 7MKX chain A
# Processing 7MKX chain C
# Processing 7MON chain A
# Processing 7MON chain B
# Processing 7MP9 chain A
# Processing 7MT8 chain G
# Processing 7MT9 chain G
# Processing 7MTA chain G
# Processing 7MTB chain G
# Processing 7MU7 chain A
# Processing 7MU7 chain B
# Processing 7MX3 chain A
# Processing 7MX3 chain B
# Processing 7MX3 chain C
# Processing 7MX3 chain D
# Processing 7MXJ chain A
# Processing 7MXK chain A
# Processing 7MYJ chain A
# Processing 7MYJ chain C
# Processing 7N3U chain A
# Processing 7N4Q chain A
# Processing 7N4R chain A
# Processing 7N4S chain A
# Processing 7N5O chain A
# Processing 7N5R chain A
# Processing 7N5X chain A
# Processing 7N5Y chain A
# Processing 7N8T chain A
# Processing 7N91 chain A
# Processing 7N91 chain B
# Processing 7N93 chain A
# Processing 7N93 chain B
# Processing 7N9G chain A
# Processing 7N9G chain B
# Processing 7N9G chain C
# Processing 7NAA chain A
# Processing 7NAA chain B
# Processing 7NAA chain C
# Processing 7NAA chain D
# Processing 7NCF chain A
# Processing 7NG7 chain A
# Processing 7NH4 chain A
# Processing 7NH5 chain A
# Processing 7NNS chain B
# Processing 7NQQ chain A
# Processing 7NQW chain A
# Processing 7NR3 chain A
# Processing 7NR5 chain A
# Processing 7NR8 chain A
# Processing 7NR9 chain A
# Processing 7NRB chain A
# Processing 7NRY chain X
# Processing 7NTH chain A
# Processing 7NTI chain A
# Processing 7NVQ chain A
# Processing 7NWK chain A
# Processing 7NXJ chain A
# Processing 7NXJ chain C
# Processing 7NXK chain A
# Processing 7NXK chain C
# Processing 7NZN chain A
# Processing 7NZY chain A
# Processing 7NZY chain B
# Processing 7NZY chain C
# Processing 7NZY chain D
# Processing 7O2V chain A
# Processing 7O7J chain A
# Processing 7O7K chain A
# Processing 7O7K chain B
# Processing 7O9Y chain A
# Processing 7OA0 chain A
# Error processing 7OA0 chain A: index 0 is out of bounds for axis 0 with size 0
# Processing 7OAI chain A
# Processing 7OAI chain B
# Processing 7OAI chain C
# Processing 7OAI chain D
# Processing 7OAJ chain A
# Processing 7OAJ chain B
# Processing 7OAJ chain C
# Processing 7OAJ chain D
# Processing 7OAK chain A
# Processing 7OAK chain B
# Processing 7OAK chain C
# Processing 7OAK chain D
# Processing 7OAL chain A
# Processing 7OAL chain B
# Processing 7OAL chain C
# Processing 7OAL chain D
# Processing 7OAM chain B
# Processing 7OLS chain A
# Processing 7OLV chain A
# Processing 7OLX chain A
# Processing 7OOV chain A
# Processing 7OPG chain A
# Processing 7OPG chain B
# Processing 7OPG chain C
# Processing 7OPM chain A
# Processing 7OPO chain A
# Processing 7OPO chain C
# Processing 7OPO chain E
# Processing 7OPO chain G
# Processing 7OPO chain I
# Processing 7OPO chain K
# Processing 7OPS chain A
# Processing 7ORE chain A
# Processing 7ORF chain A
# Processing 7OTE chain A
# Processing 7OTE chain B
# Processing 7OVI chain A
# Processing 7OVJ chain A
# Processing 7OVK chain A
# Processing 7OVL chain A
# Processing 7OVM chain A
# Processing 7OVN chain A
# Processing 7OXB chain A
# Processing 7OY5 chain A
# Processing 7OY5 chain B
# Processing 7OY6 chain C
# Processing 7OZB chain A
# Error processing 7OZB chain A: index 0 is out of bounds for axis 0 with size 0
# Processing 7OZB chain B
# Error processing 7OZB chain B: index 0 is out of bounds for axis 0 with size 0
# Processing 7OZD chain A
# Error processing 7OZD chain A: index 0 is out of bounds for axis 0 with size 0
# Processing 7OZD chain B
# Error processing 7OZD chain B: index 0 is out of bounds for axis 0 with size 0
# Processing 7OZF chain A
# Error processing 7OZF chain A: index 0 is out of bounds for axis 0 with size 0
# Processing 7OZF chain B
# Error processing 7OZF chain B: index 0 is out of bounds for axis 0 with size 0
# Processing 7OZY chain A
# Error processing 7OZY chain A: index 0 is out of bounds for axis 0 with size 0
# Processing 7OZY chain B
# Error processing 7OZY chain B: index 0 is out of bounds for axis 0 with size 0
# Processing 7P1L chain A
# Processing 7P1L chain B
# Processing 7P3V chain A
# Processing 7P3V chain B
# Processing 7P6N chain A
# Processing 7P6N chain B
# Processing 7P6N chain C
# Processing 7P6N chain D
# Processing 7P6N chain E
# Processing 7P6N chain F
# Processing 7P6N chain G
# Processing 7P6N chain H
# Processing 7P7F chain A
# Processing 7P7F chain B
# Processing 7P7F chain C
# Processing 7P7F chain D
# Processing 7P7G chain A
# Processing 7P7G chain B
# Processing 7P7H chain A
# Processing 7P7H chain B
# Processing 7PCD chain A
# Processing 7PID chain A
# Processing 7PIE chain A
# Processing 7PIF chain A
# Processing 7PIG chain A
# Processing 7PIH chain A
# Processing 7PNS chain A
# Processing 7PQS chain A
# Processing 7PQS chain B
# Processing 7PQV chain A
# Processing 7PT6 chain 8
# Processing 7PT6 chain H
# Processing 7PT7 chain 8
# Processing 7PUE chain A
# Processing 7PUS chain A
# Error processing 7PUS chain A: index 0 is out of bounds for axis 0 with size 0
# Processing 7PVU chain B
# Processing 7PWD chain A
# Processing 7Q4A chain A
# Processing 7Q4A chain B
# Processing 7Q52 chain A
# Error processing 7Q52 chain A: index 0 is out of bounds for axis 0 with size 0
# Processing 7Q6H chain A
# Error processing 7Q6H chain A: index 0 is out of bounds for axis 0 with size 0
# Processing 7Q7C chain A
# Processing 7Q7D chain A
# Processing 7Q7E chain A
# Processing 7Q7I chain A
# Processing 7Q7K chain A
# Processing 7Q7L chain A
# Processing 7Q7W chain A
# Processing 7Q8V chain A
# Processing 7Q8W chain A
# Processing 7Q8Y chain A
# Processing 7Q8Y chain B
# Processing 7Q8Z chain A
# Processing 7Q8Z chain B
# Processing 7Q90 chain A
# Processing 7Q90 chain B
# Processing 7QB2 chain A
# Processing 7QFM chain A
# Processing 7QG1 chain A
# Processing 7QG1 chain B
# Processing 7QG2 chain A
# Processing 7QG2 chain B
# Processing 7QG2 chain C
# Processing 7QG2 chain D
# Processing 7QG3 chain A
# Processing 7QG3 chain B
# Processing 7QG5 chain A
# Processing 7QG5 chain B
# Processing 7QGB chain A
# Processing 7QGC chain A
# Processing 7QGD chain A
# Processing 7QGE chain A
# Processing 7QGP chain A
# Processing 7QHG chain A
# Processing 7QHG chain B
# Processing 7QHL chain A
# Processing 7QHL chain C
# Processing 7QHW chain A
# Error processing 7QHW chain A: index 0 is out of bounds for axis 0 with size 0
# Processing 7QHW chain C
# Error processing 7QHW chain C: index 0 is out of bounds for axis 0 with size 0
# Processing 7QQ6 chain A
# Processing 7QQ6 chain B
# Processing 7QQ6 chain C
# Processing 7QQ6 chain D
# Processing 7QR9 chain A
# Processing 7QR9 chain B
# Processing 7QR9 chain C
# Processing 7QR9 chain D
# Processing 7QRA chain A
# Processing 7QRA chain B
# Processing 7QRA chain C
# Processing 7QRA chain D
# Processing 7QRB chain A
# Processing 7QRB chain B
# Processing 7QRB chain C
# Processing 7QRB chain D
# Processing 7QUE chain A
# Processing 7QUE chain B
# Processing 7QUF chain A
# Processing 7QUF chain B
# Processing 7QUX chain A
# Processing 7QWK chain A
# Processing 7QWK chain B
# Processing 7QWK chain C
# Processing 7QWK chain D
# Processing 7QWK chain E
# Processing 7QWK chain F
# Processing 7QWK chain G
# Processing 7QWK chain H
# Processing 7R60 chain A
# Processing 7R61 chain A
# Processing 7R7K chain A
# Processing 7R7R chain A
# Processing 7R9L chain A
# Processing 7R9N chain A
# Processing 7R9N chain B
# Processing 7R9P chain A
# Processing 7R9P chain B
# Processing 7R9T chain A
# Processing 7R9T chain B
# Processing 7RA5 chain A
# Processing 7REE chain A
# Processing 7RJ6 chain A
# Processing 7RJ6 chain B
# Processing 7RJ7 chain A
# Processing 7RJ7 chain B
# Processing 7RJ8 chain A
# Processing 7RJ8 chain B
# Processing 7RN6 chain A
# Processing 7RUN chain A
# Processing 7RUN chain B
# Processing 7RWE chain A
# Processing 7RWF chain A
# Processing 7RXO chain A
# Processing 7S1N chain A
# Processing 7S25 chain A
# Processing 7S25 chain B
# Processing 7S25 chain C
# Processing 7S26 chain A
# Processing 7S26 chain B
# Processing 7S26 chain C
# Processing 7S46 chain A
# Processing 7S47 chain A
# Processing 7S4T chain A
# Processing 7S6U chain A
# Processing 7S6V chain A
# Processing 7S7A chain A
# Processing 7S84 chain A
# Processing 7S85 chain A
# Processing 7S9X chain A
# Processing 7SA0 chain A
# Processing 7SHV chain A
# Processing 7SHV chain B
# Processing 7SIU chain A
# Processing 7SIU chain B
# Processing 7SJ3 chain A
# Processing 7SQM chain A
# Processing 7SUF chain A
# Processing 7SUG chain A
# Processing 7SUH chain A
# Processing 7SUI chain A
# Processing 7SUJ chain A
# Processing 7SUJ chain B
# Processing 7SXF chain A
# Processing 7SXG chain A
# Processing 7SXH chain A
# Processing 7SXJ chain A
# Processing 7SZA chain A
# Processing 7SZA chain C
# Processing 7SZB chain A
# Processing 7SZB chain C
# Processing 7SZC chain A
# Processing 7SZC chain C
# Processing 7SZD chain A
# Processing 7SZD chain C
# Processing 7SZR chain A
# Processing 7SZR chain B
# Processing 7T0P chain A
# Processing 7T0P chain B
# Processing 7T1T chain A
# Processing 7T4I chain A
# Processing 7T4J chain A
# Processing 7T4J chain B
# Processing 7T4T chain A
# Processing 7T4T chain B
# Processing 7T4U chain A
# Processing 7T4U chain B
# Processing 7T4V chain A
# Processing 7T4V chain B
# Processing 7T4W chain A
# Processing 7T4W chain B
# Processing 7T6F chain A
# Processing 7T6F chain B
# Processing 7TEU chain A
# Processing 7TNH chain A
# Processing 7U2Z chain A
# Processing 7U2Z chain B
# Processing 7U31 chain A
# Processing 7U31 chain B
# Processing 7U33 chain A
# Processing 7U33 chain B
# Processing 7U36 chain A
# Processing 7U36 chain B
# Processing 7U98 chain A
# Processing 7U98 chain B
# Processing 7U98 chain C
# Processing 7U98 chain D
# Processing 7U99 chain A
# Processing 7U9A chain A
# Processing 7UG1 chain A
# Processing 7UGB chain A
# Processing 7UIR chain A
# Processing 7UIR chain B
# Processing 7UJP chain A
# Processing 7UJP chain B
# Processing 7UJQ chain A
# Processing 7UJQ chain B
# Processing 7UJS chain A
# Processing 7UJT chain A
# Processing 7UJX chain E
# Processing 7UKV chain A
# Processing 7UKW chain B
# Processing 7UKW chain C
# Processing 7UKZ chain A
# Processing 7UKZ chain B
# Processing 7UKZ chain C
# Processing 7UKZ chain D
# Processing 7UKZ chain E
# Processing 7UKZ chain F
# Processing 7UMB chain B
# Processing 7UMB chain C
# Processing 7UOS chain A
# Processing 7UP4 chain A
# Processing 7UP4 chain B
# Processing 7UP5 chain A
# Processing 7UP5 chain B
# Processing 7UP6 chain A
# Processing 7UP7 chain A
# Processing 7UP7 chain B
# Processing 7UP8 chain A
# Processing 7UP8 chain B
# Processing 7UY0 chain A
# Processing 7UY0 chain B
# Processing 7UY3 chain A
# Processing 7UYR chain A
# Processing 7UYS chain A
# Processing 7UYT chain A
# Processing 7UYU chain A
# Processing 7UYV chain A
# Processing 7UYV chain B
# Processing 7UYV chain C
# Processing 7UYV chain D
# Processing 7UYW chain A
# Processing 7V0G chain E
# Processing 7V29 chain A
# Processing 7V29 chain B
# Processing 7V3R chain A
# Processing 7V3S chain A
# Processing 7V3V chain H
# Processing 7VDP chain A
# Processing 7VDP chain B
# Processing 7VDQ chain A
# Processing 7VDQ chain B
# Processing 7VDR chain A
# Processing 7VDR chain B
# Processing 7VDS chain A
# Processing 7VDU chain A
# Processing 7VJL chain A
# Processing 7VJL chain B
# Processing 7VKN chain A
# Processing 7VKO chain A
# Processing 7VRA chain A
# Processing 7VRE chain A
# Processing 7VTO chain A
# Processing 7VTO chain B
# Processing 7W5C chain A
# Processing 7W5O chain A
# Processing 7W5O chain B
# Processing 7W7X chain A
# Processing 7W7X chain B
# Processing 7W7Y chain A
# Processing 7W7Y chain B
# Processing 7WCL chain A
# Processing 7WCL chain B
# Processing 7WCT chain A
# Processing 7WCW chain A
# Processing 7WCX chain A
# Processing 7WF5 chain A
# Processing 7WF5 chain B
# Processing 7X4H chain A
# Processing 7X4U chain A
# Processing 7XAF chain A
# Processing 7XBI chain A
# Processing 7XC1 chain A
# Processing 7XC1 chain B
# Processing 7XDV chain A
# Processing 7XDV chain B
# Processing 7XDW chain A
# Processing 7XDW chain B
# Processing 7XDX chain A
# Processing 7XDX chain B
# Processing 7XDY chain A
# Processing 7XDY chain B
# Processing 7XHY chain A
# Processing 7XLP chain A
# Processing 7XMK chain A
# Processing 7XMK chain B
# Processing 7XNC chain A
# Processing 7XSV chain A
# Processing 7XYH chain A
# Processing 7XYH chain B
# Processing 7XZR chain A
# Processing 7XZR chain B
# Processing 7Y1G chain A
# Processing 7Y1G chain B
# Processing 7Y4T chain A
# Processing 7Y4U chain A
# Processing 7YAW chain A
# Processing 7YAW chain B
# Processing 7YAW chain C
# Processing 7YAW chain D
# Processing 7YAZ chain A
# Processing 7YBO chain A
# Processing 7YBP chain A
# Processing 7YBX chain A
# Processing 7YC1 chain A
# Processing 7YC3 chain A
# Processing 7YC9 chain A
# Processing 7YDX chain A
# Processing 7YDX chain B
# Processing 7YL1 chain A
# Processing 7Z1F chain A
# Processing 7Z1F chain B
# Processing 7Z1G chain A
# Processing 7Z39 chain A
# Processing 7Z4V chain A
# Processing 7Z5N chain A
# Processing 7Z5N chain B
# Processing 7Z5N chain C
# Processing 7Z5N chain D
# Processing 7Z5N chain E
# Processing 7Z5N chain F
# Processing 7Z5N chain G
# Processing 7Z5N chain H
# Processing 7Z5W chain A
# Processing 7Z5W chain B
# Processing 7Z5X chain A
# Processing 7Z5X chain B
# Processing 7Z6I chain A
# Error processing 7Z6I chain A: index 0 is out of bounds for axis 0 with size 0
# Processing 7Z6U chain A
# Processing 7Z9T chain A
# Error processing 7Z9T chain A: index 0 is out of bounds for axis 0 with size 0
# Processing 7Z9T chain B
# Error processing 7Z9T chain B: index 0 is out of bounds for axis 0 with size 0
# Processing 7ZH8 chain A
# Processing 7ZH8 chain B
# Processing 7ZH8 chain C
# Processing 7ZH8 chain D
# Processing 7ZHN chain A
# Processing 7ZHO chain A
# Processing 7ZHP chain A
# Processing 7ZHQ chain A
# Processing 7ZKS chain A
# Processing 7ZKX chain A
# Processing 7ZPC chain A
# Processing 7ZTL chain A
# Processing 7ZUN chain A
# Processing 7ZVS chain A
# Processing 7ZVS chain B
# Processing 7ZW8 chain A
# Processing 7ZWE chain A
# Processing 7ZWG chain A
# Processing 7ZY0 chain A
# Processing 7ZY2 chain A
# Processing 7ZY5 chain A
# Processing 7ZY5 chain B
# Processing 7ZY6 chain A
# Processing 7ZY8 chain B
# Processing 7ZYD chain A
# Processing 7ZYK chain A
# Processing 7ZYM chain A
# Processing 7ZYN chain A
# Processing 7ZYO chain A
# Processing 7ZYP chain A
# Processing 7ZYQ chain A
# Processing 7ZYQ chain B
# Processing 7ZYR chain A
# Processing 8A27 chain A
# Processing 8A2A chain A
# Processing 8A2B chain A
# Processing 8A2D chain A
# Processing 8A5J chain A
# Processing 8A5J chain B
# Processing 8A66 chain A
# Processing 8A66 chain B
# Processing 8A8M chain A
# Processing 8A8M chain B
# Processing 8AAU chain L
# Processing 8ACM chain A
# Error processing 8ACM chain A: index 0 is out of bounds for axis 0 with size 0
# Processing 8ACO chain A
# Error processing 8ACO chain A: index 0 is out of bounds for axis 0 with size 0
# Processing 8AE7 chain A
# Processing 8AEC chain A
# Processing 8AEK chain A
# Processing 8AEM chain A
# Processing 8AFR chain A
# Processing 8AHG chain A
# Processing 8AHH chain A
# Processing 8AHI chain A
# Processing 8AK3 chain A
# Processing 8AN8 chain A
# Processing 8AN8 chain B
# Processing 8ANS chain A
# Processing 8AO2 chain A
# Processing 8AO3 chain A
# Processing 8AO4 chain A
# Processing 8AO5 chain A
# Processing 8AO6 chain A
# Processing 8AO7 chain A
# Processing 8AO8 chain A
# Processing 8AO9 chain A
# Processing 8AOA chain A
# Processing 8AOB chain A
# Processing 8AOC chain A
# Processing 8AOD chain A
# Processing 8AOE chain A
# Processing 8AOF chain A
# Processing 8AOG chain A
# Processing 8AOH chain A
# Processing 8AOI chain A
# Processing 8AOJ chain A
# Processing 8ARJ chain A
# Processing 8ATB chain A
# Error processing 8ATB chain A: index 0 is out of bounds for axis 0 with size 0
# Processing 8ATB chain B
# Error processing 8ATB chain B: index 0 is out of bounds for axis 0 with size 0
# Processing 8ATL chain A
# Error processing 8ATL chain A: index 0 is out of bounds for axis 0 with size 0
# Processing 8ATL chain B
# Error processing 8ATL chain B: index 0 is out of bounds for axis 0 with size 0
# Processing 8ATN chain A
# Error processing 8ATN chain A: index 0 is out of bounds for axis 0 with size 0
# Processing 8ATN chain B
# Error processing 8ATN chain B: index 0 is out of bounds for axis 0 with size 0
# Processing 8AU3 chain A
# Processing 8AU3 chain B
# Processing 8AU5 chain A
# Processing 8AUZ chain A
# Processing 8AUZ chain B
# Processing 8AV1 chain A
# Processing 8AV1 chain B
# Processing 8AW1 chain A
# Processing 8AW1 chain B
# Processing 8B54 chain A
# Processing 8B54 chain C
# Processing 8B8N chain A
# Processing 8B8U chain A
# Processing 8B8U chain B
# Processing 8B99 chain A
# Processing 8B9E chain A
# Processing 8B9H chain A
# Processing 8BA2 chain A
# Processing 8BA3 chain A
# Processing 8BA4 chain A
# Processing 8BAB chain A
# Processing 8BAK chain A
# Processing 8BEM chain A
# Processing 8BEM chain B
# Processing 8BEM chain D
# Processing 8BEM chain G
# Processing 8BFM chain A
# Processing 8BFS chain A
# Processing 8BGC chain A
# Processing 8BGC chain B
# Processing 8BI2 chain A
# Processing 8BIN chain A
# Processing 8BIO chain A
# Processing 8BJT chain A
# Processing 8BJU chain A
# Processing 8BK0 chain A
# Processing 8BM2 chain A
# Processing 8BM2 chain B
# Processing 8BOC chain A
# Processing 8BOD chain A
# Processing 8BOF chain A
# Processing 8BOG chain A
# Processing 8BOH chain A
# Processing 8BOI chain A
# Processing 8BOK chain A
# Processing 8BOM chain A
# Processing 8BPV chain A
# Processing 8BPW chain A
# Processing 8BPW chain B
# Processing 8BR5 chain A
# Error processing 8BR5 chain A: index 0 is out of bounds for axis 0 with size 0
# Processing 8BR5 chain B
# Error processing 8BR5 chain B: index 0 is out of bounds for axis 0 with size 0
# Processing 8BR5 chain C
# Error processing 8BR5 chain C: index 0 is out of bounds for axis 0 with size 0
# Processing 8BR5 chain D
# Error processing 8BR5 chain D: index 0 is out of bounds for axis 0 with size 0
# Processing 8BR6 chain A
# Error processing 8BR6 chain A: index 0 is out of bounds for axis 0 with size 0
# Processing 8BR6 chain B
# Error processing 8BR6 chain B: index 0 is out of bounds for axis 0 with size 0
# Processing 8BR7 chain A
# Error processing 8BR7 chain A: index 0 is out of bounds for axis 0 with size 0
# Processing 8BR7 chain B
# Error processing 8BR7 chain B: index 0 is out of bounds for axis 0 with size 0
# Processing 8BU1 chain B
# Processing 8BU1 chain E
# Processing 8BU1 chain H
# Processing 8BU2 chain B
# Processing 8BU2 chain H
# Processing 8BU3 chain B
# Processing 8BU3 chain E
# Processing 8BU3 chain H
# Processing 8BU4 chain B
# Processing 8BU4 chain E
# Processing 8BU4 chain H
# Processing 8BU5 chain B
# Processing 8BU5 chain E
# Processing 8BU5 chain H
# Processing 8BU6 chain B
# Processing 8BU6 chain E
# Processing 8BU6 chain H
# Processing 8BU7 chain E
# Processing 8BU9 chain B
# Processing 8BU9 chain E
# Processing 8BU9 chain H
# Processing 8BUA chain B
# Processing 8BUA chain E
# Processing 8BUA chain H
# Processing 8BUB chain B
# Processing 8BUB chain E
# Processing 8BUB chain H
# Processing 8BUC chain B
# Processing 8BUC chain E
# Processing 8BUC chain H
# Processing 8BUD chain B
# Processing 8BUD chain H
# Processing 8BUE chain B
# Processing 8BUE chain E
# Processing 8BUE chain H
# Processing 8BUF chain B
# Processing 8BUF chain E
# Processing 8BUF chain H
# Processing 8BUG chain B
# Processing 8BUH chain B
# Processing 8BUH chain E
# Processing 8BUH chain H
# Processing 8BUI chain B
# Processing 8BUI chain E
# Processing 8BUI chain H
# Processing 8BUJ chain B
# Processing 8BUJ chain E
# Processing 8BUJ chain H
# Processing 8BUK chain B
# Processing 8BUK chain E
# Processing 8BUK chain H
# Processing 8BUL chain B
# Processing 8BUL chain E
# Processing 8BUL chain H
# Processing 8BUM chain B
# Processing 8BUM chain E
# Processing 8BUM chain H
# Processing 8BUN chain B
# Processing 8BUN chain E
# Processing 8BUN chain H
# Processing 8BUO chain B
# Processing 8BUO chain E
# Processing 8BUO chain H
# Processing 8BUP chain B
# Processing 8BUP chain E
# Processing 8BUP chain H
# Processing 8BUQ chain B
# Processing 8BUQ chain E
# Processing 8BUQ chain H
# Processing 8BUR chain B
# Processing 8BUR chain E
# Processing 8BUR chain H
# Processing 8BUS chain B
# Processing 8BUS chain E
# Processing 8BUS chain H
# Processing 8BUT chain B
# Processing 8BUT chain E
# Processing 8BUT chain H
# Processing 8BW9 chain C
# Processing 8BX6 chain A
# Processing 8BX9 chain A
# Processing 8BX9 chain B
# Processing 8BXC chain A
# Processing 8BXC chain B
# Processing 8BXH chain A
# Processing 8BZI chain A
# Processing 8BZJ chain A
# Processing 8BZJ chain B
# Processing 8BZP chain A
# Processing 8BZP chain B
# Processing 8C08 chain A
# Processing 8C08 chain B
# Processing 8C0A chain A
# Processing 8C0A chain B
# Processing 8C14 chain A
# Processing 8C15 chain A
# Processing 8C1D chain A
# Processing 8C1E chain A
# Processing 8C1F chain A
# Processing 8C1G chain A
# Processing 8C1H chain A
# Processing 8C1I chain A
# Processing 8C1K chain A
# Processing 8C1M chain A
# Processing 8C2Z chain A
# Processing 8C3G chain A
# Processing 8C3G chain B
# Processing 8C3G chain C
# Processing 8C3G chain D
# Processing 8C3Q chain A
# Processing 8C3Q chain B
# Processing 8C3R chain A
# Processing 8C3R chain B
# Processing 8C5Q chain A
# Processing 8C5Q chain B
# Processing 8C7W chain A
# Processing 8C7X chain A
# Processing 8C7X chain B
# Processing 8C7Y chain A
# Processing 8C7Y chain B
# Processing 8C7Z chain A
# Processing 8CDW chain A
# Processing 8CDW chain B
# Processing 8CGC chain A
# Processing 8CHF chain A
# Processing 8CHF chain B
# Processing 8CIE chain A
# Processing 8CIJ chain A
# Processing 8CUR chain A
# Processing 8D6C chain A
# Processing 8D6C chain B
# Processing 8D6D chain A
# Processing 8D6D chain B
# Processing 8D6E chain A
# Processing 8D6E chain B
# Processing 8D6F chain A
# Processing 8D6F chain B
# Processing 8D73 chain A
# Processing 8D73 chain B
# Processing 8D76 chain A
# Processing 8D76 chain B
# Processing 8DEG chain A
# Processing 8DGS chain A
# Processing 8DGS chain B
# Processing 8DGT chain A
# Processing 8DGT chain B
# Processing 8DJC chain A
# Processing 8DJC chain B
# Processing 8DJD chain A
# Processing 8DJD chain B
# Processing 8DJE chain A
# Processing 8DJE chain B
# Processing 8DKS chain A
# Processing 8DKS chain B
# Processing 8DQT chain A
# Processing 8DSO chain B
# Processing 8DSW chain A
# Processing 8E1X chain A
# Processing 8E1X chain B
# Processing 8E2M chain A
# Processing 8E4T chain A
# Processing 8E80 chain A
# Processing 8E81 chain A
# Processing 8EDH chain A
# Processing 8EFJ chain A
# Processing 8EJB chain A
# Processing 8ELC chain A
# Processing 8EM8 chain A
# Processing 8EME chain B
# Processing 8ENJ chain A
# Processing 8EQ5 chain A
# Processing 8EQ9 chain A
# Error processing 8EQ9 chain A: index 0 is out of bounds for axis 0 with size 0
# Processing 8EQD chain A
# Error processing 8EQD chain A: index 0 is out of bounds for axis 0 with size 0
# Processing 8EQE chain A
# Error processing 8EQE chain A: index 0 is out of bounds for axis 0 with size 0
# Processing 8ERD chain A
# Processing 8ERN chain A
# Processing 8EWY chain A
# Processing 8EWY chain B
# Processing 8EX0 chain A
# Processing 8EX1 chain A
# Processing 8EX2 chain A
# Processing 8F1H chain A
# Processing 8F1W chain A
# Processing 8F1W chain B
# Processing 8F1W chain C
# Processing 8F1W chain D
# Processing 8F1X chain A
# Processing 8F1Y chain A
# Processing 8F1Z chain A
# Processing 8F7O chain A
# Processing 8F7O chain B
# Processing 8F7P chain A
# Processing 8F7P chain B
# Processing 8FD9 chain A
# Processing 8FE2 chain A
# Processing 8FE2 chain B
# Processing 8FE5 chain A
# Processing 8FE5 chain B
# Processing 8FE9 chain A
# Processing 8FEC chain A
# Processing 8FEC chain B
# Processing 8FF0 chain A
# Processing 8FF8 chain A
# Processing 8FF8 chain B
# Processing 8FH4 chain A
# Processing 8FH4 chain B
# Processing 8FH4 chain C
# Processing 8FH4 chain D
# Processing 8FJZ chain A
# Processing 8FJZ chain B
# Processing 8FJZ chain C
# Processing 8FJZ chain D
# Processing 8FJZ chain E
# Processing 8FJZ chain F
# Processing 8FKO chain A
# Processing 8FKO chain B
# Processing 8FKO chain C
# Processing 8FKO chain D
# Processing 8FKO chain E
# Processing 8FLG chain A
# Processing 8FLH chain A
# Processing 8FLL chain A
# Processing 8FLN chain A
# Processing 8FLV chain A
# Processing 8FO2 chain E
# Processing 8FO7 chain C
# Processing 8FO8 chain C
# Processing 8FO8 chain E
# Processing 8FO9 chain A
# Processing 8FO9 chain C
# Processing 8FO9 chain E
# Processing 8FO9 chain F
# Processing 8FOW chain A
# Processing 8FP0 chain A
# Processing 8FP1 chain A
# Processing 8FP3 chain A
# Processing 8FP5 chain A
# Processing 8FV3 chain A
# Processing 8FV3 chain B
# Processing 8FV3 chain C
# Processing 8FV3 chain D
# Processing 8FV4 chain A
# Processing 8FV4 chain C
# Processing 8FV4 chain D
# Processing 8G63 chain A
# Processing 8G6Z chain A
# Processing 8G6Z chain B
# Processing 8G8O chain A
# Processing 8G8O chain B
# Processing 8G8X chain A
# Processing 8G8X chain B
# Processing 8GB4 chain A
# Processing 8GB4 chain B
# Processing 8GB4 chain C
# Processing 8GB4 chain D
# Processing 8GC7 chain A
# Processing 8GC8 chain A
# Processing 8GDS chain A
# Processing 8GDS chain B
# Processing 8GDS chain C
# Processing 8GDS chain D
# Processing 8GMB chain A
# Processing 8GMC chain A
# Processing 8GMC chain B
# Processing 8GMD chain A
# Processing 8GMD chain B
# Processing 8GUW chain A
# Processing 8GUW chain B
# Processing 8GUW chain C
# Processing 8GVJ chain A
# Processing 8H4R chain A
# Processing 8H59 chain A
# Processing 8H6P chain A
# Processing 8H6T chain A
# Processing 8H75 chain A
# Processing 8H75 chain B
# Processing 8H75 chain C
# Processing 8H75 chain D
# Processing 8H7F chain A
# Processing 8H7F chain B
# Processing 8H7H chain A
# Processing 8H7H chain B
# Processing 8H7X chain A
# Processing 8HAQ chain A
# Processing 8HAQ chain B
# Processing 8HLT chain A
# Processing 8HLT chain B
# Processing 8HMT chain A
# Processing 8HMT chain B
# Processing 8HMT chain C
# Processing 8HMT chain D
# Processing 8HOA chain A
# Processing 8HOD chain A
# Processing 8HV1 chain A
# Processing 8HV2 chain A
# Processing 8HV3 chain A
# Processing 8HV4 chain A
# Processing 8HV5 chain A
# Processing 8HV6 chain A
# Processing 8HV7 chain A
# Processing 8HV8 chain A
# Processing 8HV9 chain A
# Processing 8HVA chain A
# Processing 8HY7 chain A
# Processing 8I0L chain A
# Processing 8I0M chain A
# Processing 8I2N chain A
# Processing 8I2N chain B
# Processing 8IE5 chain A
# Processing 8IE6 chain A
# Processing 8IE7 chain A
# Processing 8IE8 chain A
# Processing 8J5W chain A
# Processing 8J5X chain A
# Processing 8J61 chain A
# Processing 8J63 chain A
# Processing 8JF3 chain A
# Processing 8JF3 chain B
# Processing 8JF4 chain A
# Processing 8JMX chain A
# Processing 8JMZ chain A
# Processing 8JMZ chain B
# Processing 8JOT chain A
# Processing 8JPB chain G
# Processing 8JPC chain G
# Processing 8JPD chain G
# Processing 8JUP chain A
# Processing 8JUV chain A
# Processing 8K5R chain A
# Processing 8OF5 chain A
# Processing 8OKU chain A
# Processing 8OKU chain B
# Processing 8ORM chain J
# Processing 8OUR chain A
# Processing 8OUS chain A
# Processing 8OUT chain A
# Processing 8OUU chain A
# Processing 8OUU chain B
# Processing 8OUV chain A
# Processing 8OUV chain B
# Processing 8OV7 chain A
# Processing 8OVZ chain A
# Processing 8OVZ chain B
# Processing 8OW3 chain A
# Processing 8OWG chain A
# Processing 8OWG chain B
# Processing 8OWG chain C
# Processing 8OY2 chain A
# Processing 8P04 chain A
# Processing 8P05 chain A
# Processing 8P05 chain B
# Processing 8P06 chain A
# Processing 8P06 chain B
# Processing 8P07 chain A
# Processing 8P07 chain B
# Processing 8P08 chain A
# Processing 8P4Z chain A
# Processing 8P4Z chain B
# Processing 8P6V chain J
# Processing 8P6W chain J
# Processing 8P6X chain J
# Processing 8P6Y chain J
# Processing 8P6Z chain J
# Processing 8P70 chain J
# Processing 8P71 chain J
# Processing 8P72 chain J
# Processing 8P73 chain J
# Processing 8P74 chain J
# Processing 8P75 chain J
# Processing 8P76 chain J
# Processing 8P77 chain J
# Processing 8P78 chain J
# Processing 8P7J chain A
# Processing 8P7J chain B
# Processing 8P7L chain J
# Processing 8P81 chain A
# Processing 8PLZ chain J
# Processing 8PM3 chain A
# Processing 8PM3 chain B
# Processing 8PM3 chain C
# Processing 8PM3 chain D
# Processing 8PQ9 chain A
# Processing 8PQ9 chain C
# Processing 8PQA chain A
# Processing 8PQA chain C
# Processing 8PQB chain A
# Processing 8PQC chain A
# Processing 8PQC chain B
# Processing 8PQD chain A
# Processing 8PQD chain B
# Processing 8PQE chain A
# Processing 8PQE chain B
# Processing 8PQF chain A
# Processing 8PQF chain C
# Processing 8PQG chain A
# Processing 8PQG chain C
# Processing 8PQH chain A
# Processing 8PQI chain A
# Processing 8PVO chain A
# Processing 8PVO chain B
# Processing 8PVP chain A
# Processing 8PVP chain B
# Processing 8PYI chain A
# Error processing 8PYI chain A: index 0 is out of bounds for axis 0 with size 0
# Processing 8PYI chain B
# Error processing 8PYI chain B: index 0 is out of bounds for axis 0 with size 0
# Processing 8PYI chain C
# Error processing 8PYI chain C: index 0 is out of bounds for axis 0 with size 0
# Processing 8PYI chain D
# Error processing 8PYI chain D: index 0 is out of bounds for axis 0 with size 0
# Processing 8PYI chain E
# Error processing 8PYI chain E: index 0 is out of bounds for axis 0 with size 0
# Processing 8PYI chain F
# Error processing 8PYI chain F: index 0 is out of bounds for axis 0 with size 0
# Processing 8PYI chain G
# Error processing 8PYI chain G: index 0 is out of bounds for axis 0 with size 0
# Processing 8PYI chain H
# Error processing 8PYI chain H: index 0 is out of bounds for axis 0 with size 0
# Processing 8PYJ chain A
# Error processing 8PYJ chain A: index 0 is out of bounds for axis 0 with size 0
# Processing 8PYK chain A
# Error processing 8PYK chain A: index 0 is out of bounds for axis 0 with size 0
# Processing 8PYL chain A
# Error processing 8PYL chain A: index 0 is out of bounds for axis 0 with size 0
# Processing 8PYM chain A
# Error processing 8PYM chain A: index 0 is out of bounds for axis 0 with size 0
# Processing 8PYN chain A
# Error processing 8PYN chain A: index 0 is out of bounds for axis 0 with size 0
# Processing 8Q1Z chain A
# Processing 8Q61 chain A
# Processing 8Q77 chain A
# Processing 8Q9S chain A
# Processing 8QBU chain A
# Processing 8QCD chain A
# Processing 8QCG chain A
# Processing 8QCG chain B
# Processing 8QEL chain B
# Processing 8QF1 chain A
# Processing 8QLQ chain A
# Processing 8QLR chain A
# Processing 8QLR chain B
# Processing 8QLS chain A
# Processing 8QLT chain A
# Processing 8QQG chain A
# Processing 8QQG chain B
# Processing 8QQG chain C
# Processing 8QQY chain A
# Processing 8QWY chain A
# Processing 8QWY chain B
# Processing 8QWZ chain A
# Processing 8QWZ chain B
# Processing 8R10 chain A
# Processing 8R18 chain A
# Processing 8R1N chain A
# Processing 8R1P chain A
# Processing 8R1T chain A
# Processing 8R4O chain A
# Processing 8R4O chain C
# Processing 8R4O chain E
# Processing 8R4O chain G
# Processing 8R4O chain I
# Processing 8R4O chain K
# Processing 8R4Q chain A
# Processing 8R4Q chain C
# Processing 8R4Q chain E
# Processing 8R4Q chain G
# Processing 8R4Q chain I
# Processing 8R4Q chain K
# Processing 8R4U chain A
# Processing 8R4U chain C
# Processing 8R4U chain E
# Processing 8R4U chain G
# Processing 8R4V chain A
# Processing 8R4V chain B
# Processing 8R4V chain C
# Processing 8R7G chain A
# Processing 8R7G chain B
# Processing 8R7G chain C
# Processing 8R7G chain D
# Processing 8RDK chain A
# Processing 8S3X chain A
# Processing 8S3X chain B
# Processing 8S3X chain C
# Processing 8S3X chain D
# Processing 8S93 chain A
# Processing 8S98 chain A
# Processing 8S98 chain B
# Processing 8S98 chain C
# Processing 8S99 chain A
# Processing 8S99 chain B
# Processing 8S99 chain C
# Processing 8S9A chain A
# Processing 8S9A chain B
# Processing 8S9A chain C
# Processing 8S9F chain A
# Processing 8S9F chain B
# Processing 8SF8 chain A
# Processing 8SIV chain A
# Processing 8SIW chain A
# Processing 8SIW chain B
# Processing 8SIX chain A
# Processing 8SMC chain C
# Processing 8SOR chain A
# Processing 8SSN chain A
# Processing 8SSN chain B
# Processing 8SSO chain A
# Processing 8SSO chain D
# Processing 8SSP chain A
# Processing 8STG chain A
# Processing 8STG chain B
# Processing 8SV9 chain A
# Processing 8SV9 chain B
# Processing 8SWE chain A
# Processing 8SWE chain B
# Processing 8TB5 chain A
# Processing 8TB5 chain B
# Processing 8TB6 chain A
# Processing 8TB6 chain B
# Processing 8TJL chain A
# Processing 8TUC chain A
# Processing 8TXY chain A
# Processing 8TXY chain B
# Processing 8TXZ chain A
# Processing 8TYQ chain A
# Processing 8TZB chain A
# Processing 8TZC chain A
# Processing 8TZE chain A
# Processing 8TZF chain A
# Processing 8TZG chain A
# Processing 8TZH chain A
# Processing 8U1F chain A
# Processing 8U1F chain B
# Processing 8U2D chain A
# Processing 8U2E chain A
# Processing 8U2O chain A
# Processing 8U2O chain B
# Processing 8U37 chain A
# Processing 8U7H chain C
# Processing 8U7L chain A
# Processing 8U7L chain B
# Processing 8U8A chain B
# Processing 8U8A chain C
# Processing 8U8B chain A
# Processing 8U8B chain B
# Processing 8U8J chain A
# Processing 8U8K chain A
# Processing 8UAK chain A
# Processing 8UAP chain A
# Processing 8UAQ chain A
# Processing 8UDT chain A
# Processing 8UDT chain B
# Processing 8UDT chain C
# Processing 8UDU chain A
# Processing 8UDU chain B
# Processing 8UDV chain A
# Processing 8UDV chain B
# Processing 8UDV chain C
# Processing 8UV0 chain A
# Processing 8UYH chain A
# Processing 8UYH chain B
# Processing 8UYI chain A
# Processing 8UYI chain B
# Processing 8VQ3 chain A
# Processing 8VQ4 chain A
# Processing 8WD4 chain A
# Processing 8WGF chain A
# Processing 8WJY chain A
# Processing 8WM0 chain A
# Processing 8WSW chain A
# Processing 8WSW chain B
# Processing 8WSW chain C
# Processing 8WSW chain D
# Processing 8WTF chain A
# Processing 8X2A chain A
# Processing 8X5K chain A
# Processing 8X5L chain A
# Processing 8X5L chain B
# Processing 8X5M chain A
# Processing 8X72 chain A
# Processing 8XFM chain A
# Processing 8XFY chain A
# Processing 8XFY chain B
# Processing 8XFY chain C
# Processing 8XFY chain D
# Processing 8XFY chain E
# Processing 8XFY chain F
# Processing 8XFY chain G
# Processing 8XFY chain H
# Processing 8XFY chain I
# Processing 8XFY chain J
# Processing 8XLO chain A
# Processing 8XLO chain B
# Processing 8XLQ chain A
# Processing 8XN8 chain A
# Processing 8XOV chain A
# Processing 8XOX chain A
# Processing 8XPV chain A
# Processing 8YGW chain A
# Processing 8YHF chain A
# Processing 8YHL chain A
# Processing 8YHW chain A
# Processing 8YHW chain B
# Processing 8YHW chain C
# Processing 8YHW chain D
# Processing 9AV7 chain A

# %% [markdown]
# ## CATION: MMSEQS2
# Here, the `run-mmseq.sh` script needs to be run. Here, the `min-seq-id` was set to 0.3:
#
# ```
# bash ./run-mmseq.sh /home/vit/Projects/LBS-pLM/data/filtering 0.3
# ```

# %%
import csv

cluster_dict = {}
with open('/home/vit/Projects/LBS-pLM/data/filtering/clusterRes_cluster.tsv', 'r') as f:
    reader = csv.reader(f, delimiter='\t')
    cluster_dict = {}
    for row in reader:
        cluster_id = row[0]
        sequence_id = row[1]
        if cluster_id not in cluster_dict:
            cluster_dict[cluster_id] = []
        cluster_dict[cluster_id].append(sequence_id)

# %%
overlapping_train_sequences = []
overall_count = 0
for cluster_id, sequences in cluster_dict.items():
    sequences_from_train = [seq.split('-')[0] for seq in sequences if seq.endswith('-TRAIN')]
    if any(seq.endswith('-TEST') for seq in sequences):
        if len(sequences_from_train) > 0:
            overall_count += sum([seq.endswith('-TEST') for seq in sequences])
            overlapping_train_sequences.extend(sequences_from_train)

print(f'Number of overlapping training sequences: {len(overlapping_train_sequences)}')
print('Overlapping training sequences:')
print(overlapping_train_sequences)
print(f'Overall overlapping test sequences: {overall_count}')
# Out:
# Number of overlapping training sequences: 57
# Overlapping training sequences:
# ['P34947', 'P32298', 'P43250', 'Q13976', 'Q13237', 'Q14012', 'Q16644', 'Q96S44', 'P11309', 'Q9UQB9', 'Q96GD4', 'P17612', 'P23458', 'O60674', 'P52333', 'Q9UHD2', 'Q9UIK4', 'O14920', 'O15111', 'Q5S007', 'Q9P1W9', 'Q05823', 'Q15208', 'Q99986', 'P68400', 'P19784', 'P54646', 'Q13131', 'Q02750', 'Q00532', 'P43403', 'Q13557', 'Q13555', 'Q9UQM7', 'Q8WU08', 'Q15759', 'O15264', 'Q16539', 'P53778', 'P27361', 'Q8TDX7', 'P49841', 'P24941', 'P06493', 'Q00535', 'Q00534', 'P31751', 'P31749', 'P48729', 'P49674', 'P07948', 'P06239', 'P09769', 'P41240', 'Q13882', 'P06241', 'P12931']
# Overall overlapping test sequences: 3645

# %% [markdown]
# # Create filtered dataset
# Loop over the dataset CSV and filter it. Save the filtered dataset.

# %%
with open('/home/vit/Projects/LBS-pLM/data/full-LIGYSIS/full-train.txt', 'r') as f:
    reader = csv.reader(f, delimiter=';')
    with open('/home/vit/Projects/LBS-pLM/data/filtered-LIGYSIS/filtered-train.txt', 'w') as out_f:
        for row in reader:
            seq_id = row[0]
            if seq_id not in overlapping_train_sequences:
                out_f.write(';'.join(row) + '\n')
